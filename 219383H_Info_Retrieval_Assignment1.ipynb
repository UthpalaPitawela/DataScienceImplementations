# %% [markdown]
# <a href="https://colab.research.google.com/github/UthpalaPitawela/Data_Science_Implementations/blob/main/219383H_Info_Retrieval_Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Read text from student feedback, research paper and twitter texts

# %%
def read_file(filename):
    "Read the contents of FILENAME and return as a string."
    infile = open(filename) # windows users should use codecs.open after importing codecs
    contents = infile.read()
    infile.close()
    return contents

# %%
student_feedback =  read_file("/content/student_feedback.txt")
twitter = read_file("/content/twitter.txt")
research_paper = read_file("/content/research_paper.txt")

# %% [markdown]
# Question 01: Tokenizer

# %% [markdown]
# NLTK TweetTokenizer will be used

# %%
from nltk.tokenize import TweetTokenizer
tknzr = TweetTokenizer(strip_handles=True, reduce_len=True)

tokenized_student_feedback = tknzr.tokenize(student_feedback)
tokenized_twitter = tknzr.tokenize(twitter)
tokenized_research_paper = tknzr.tokenize(research_paper)

# %%
tokenized_student_feedback
# Out:
# ['Honestly',
#  'last',
#  'seven',
#  'lectures',
#  'are',
#  'good',
#  '.',
#  'Lectures',
#  'are',
#  'understandable',
#  '.',
#  'Lecture',
#  'slides',
#  'are',
#  'very',
#  'useful',
#  'to',
#  'self-study',
#  'also',
#  '.',
#  'The',
#  'given',
#  'opportunity',
#  'to',
#  'ask',
#  'questions',
#  'from',
#  'the',
#  'lecturer',
#  'is',
#  'appreciative',
#  '.',
#  '"',
#  'Good',
#  ':)',
#  '<',
#  'br',
#  '/',
#  '>',
#  'please',
#  'do',
#  'recap',
#  'at',
#  'class',
#  'starting',
#  "it's",
#  'better',
#  'for',
#  'us',
#  '.',
#  '<',
#  'br',
#  '/',
#  '>',
#  'sometimes',
#  'teaching',
#  'speed',
#  'is',
#  'very',
#  'high',
#  '.',
#  '<',
#  'br',
#  '/',
#  '>',
#  '<',
#  'br',
#  '/',
#  '>',
#  'Thanks',
#  '!',
#  ':)',
#  '<',
#  'br',
#  '/',
#  '>',
#  '"',
#  'The',
#  'lectures',
#  'are',
#  'good',
#  '..',
#  'but',
#  'a',
#  'bit',
#  'speed',
#  '.',
#  'A',
#  'in',
#  'class',
#  'working',
#  'activity',
#  'is',
#  'a',
#  'must',
#  'one.So',
#  'please',
#  'take',
#  'another',
#  'hour',
#  'in',
#  'thursdays',
#  'madame',
#  '.',
#  '"',
#  '<',
#  'br',
#  '/',
#  '>',
#  'We',
#  'can',
#  'hear',
#  'your',
#  'voice',
#  'clearly',
#  'and',
#  'can',
#  'understand',
#  'the',
#  'things',
#  'you',
#  'teach',
#  '.',
#  'Presentation',
#  'slides',
#  'also',
#  'good',
#  'source',
#  'to',
#  'refer',
#  '.',
#  'lf',
#  'you',
#  'can',
#  'do',
#  'more',
#  'example',
#  'questions',
#  'within',
#  'the',
#  'classroom',
#  'and',
#  'it',
#  'will',
#  'help',
#  'us',
#  'to',
#  'understand',
#  'the',
#  'principles',
#  'well',
#  '.',
#  '<',
#  'br',
#  '/',
#  '>',
#  '"',
#  'Lectures',
#  'was',
#  'well',
#  'structured',
#  'and',
#  'well',
#  'organized',
#  '.',
#  'It',
#  'was',
#  'easy',
#  'to',
#  'understand',
#  '.',
#  'Lecture',
#  'slides',
#  'and',
#  'labs',
#  'were',
#  'also',
#  'well',
#  'organized',
#  '.',
#  'Lectures',
#  'were',
#  'good',
#  '.',
#  'understandable',
#  '.',
#  'The',
#  'lecture',
#  'slides',
#  'were',
#  'well',
#  'organized',
#  'and',
#  'the',
#  'examples',
#  'done',
#  'in',
#  'the',
#  'class',
#  'helped',
#  'a',
#  'lot',
#  'to',
#  'learn',
#  'this',
#  'new',
#  'language',
#  'and',
#  'also',
#  'the',
#  'principles',
#  'of',
#  'OOP',
#  '.',
#  'Motivated',
#  'to',
#  'well',
#  '.',
#  'Would',
#  'have',
#  'been',
#  'better',
#  'if',
#  'we',
#  'discussed',
#  'more',
#  'about',
#  'the',
#  'solutions',
#  'of',
#  'coding',
#  'exercisers',
#  '.',
#  'I',
#  'think',
#  'i',
#  'learned',
#  'a',
#  'lot',
#  'from',
#  'the',
#  'codes',
#  'you',
#  'write',
#  'in',
#  'the',
#  'board',
#  '.',
#  'When',
#  'i',
#  'compare',
#  'my',
#  'codes',
#  'with',
#  'yours',
#  'i',
#  'can',
#  'learn',
#  'about',
#  'my',
#  'mistakes',
#  'and',
#  'good',
#  'coding',
#  'practices',
#  'that',
#  'i',
#  'should',
#  'follow',
#  '.',
#  'There',
#  'fore',
#  'i',
#  'think',
#  'it',
#  'would',
#  'be',
#  'great',
#  'if',
#  'we',
#  'can',
#  'discuss',
#  'more',
#  'examples',
#  'in',
#  'the',
#  'class',
#  '.',
#  'madam',
#  'explained',
#  'the',
#  'oop',
#  'concepts',
#  'clearly',
#  'with',
#  'examples.lectures',
#  'were',
#  'interesting.we',
#  'want',
#  'more',
#  'scenario',
#  'examples',
#  'and',
#  'answers',
#  'with',
#  'explanations',
#  'in',
#  'future',
#  '.',
#  'I',
#  'satisfy',
#  'about',
#  'first',
#  '7',
#  'lectures',
#  '.',
#  'That',
#  'way',
#  'of',
#  'teaching',
#  'is',
#  'really',
#  'good',
#  'for',
#  'coming',
#  'lectures',
#  'too',
#  '.',
#  'lectuers',
#  'are',
#  'very',
#  'good',
#  '.',
#  'take',
#  'good',
#  'effort',
#  'to',
#  'make',
#  'undersatand',
#  'every',
#  'student',
#  'in',
#  'the',
#  'room',
#  '.',
#  'very',
#  'helpfull',
#  '.',
#  'I',
#  'was',
#  'able',
#  'to',
#  'obtain',
#  'a',
#  'clear',
#  'picture',
#  'about',
#  'OOP',
#  'and',
#  'its',
#  'concepts',
#  '.',
#  '"',
#  'lecture',
#  'slides',
#  ',',
#  'explanations',
#  'were',
#  'very',
#  'clear',
#  '.',
#  '<',
#  'br',
#  '/',
#  '>',
#  "it's",
#  'very',
#  'good',
#  'to',
#  'letting',
#  'ask',
#  'questions',
#  'and',
#  'explain',
#  'again',
#  'with',
#  'suitable',
#  'examples',
#  '.',
#  '<',
#  'br',
#  '/',
#  '>',
#  'sometimes',
#  ',',
#  'some',
#  'codes',
#  'on',
#  'white',
#  'board',
#  'were',
#  'unclear',
#  'at',
#  'the',
#  'back',
#  '.',
#  '<',
#  'br',
#  '/',
#  '>',
#  'overall',
#  'very',
#  'good',
#  '!',
#  '!',
#  '!',
#  '<',
#  'br',
#  '/',
#  '>',
#  '"',
#  'The',
#  'lectures',
#  'were',
#  'good',
#  'and',
#  'clear',
#  '.',
#  'And',
#  'they',
#  "weren't",
#  'too',
#  'fast',
#  '.',
#  'Writing',
#  'code',
#  'was',
#  'somewhat',
#  'confusing',
#  'because',
#  'I',
#  "didn't",
#  'know',
#  'java',
#  'before',
#  '.',
#  'Actually',
#  'teaching',
#  'is',
#  'very',
#  'good',
#  'and',
#  'can',
#  'understand',
#  'easily',
#  'the',
#  'concepts',
#  'by',
#  'examples',
#  'which',
#  'are',
#  'given',
#  'in',
#  'the',
#  'class.it',
#  'will',
#  'be',
#  'more',
#  'helpful',
#  'if',
#  'provide',
#  'solved',
#  'questions',
#  'as',
#  'well',
#  '!',
#  '.',
#  'thankyou']

# %%
tokenized_twitter
# Out:
# ['Reminds',
#  'me',
#  'of',
#  'Liberal',
#  'Immigration',
#  'Fraudster',
#  'Monsef',
#  'avoiding',
#  'deportation',
#  'from',
#  'Canada',
#  '.',
#  '#cdnpoli',
#  '#LPC',
#  '#CPCLDR',
#  '�',
#  '�',
#  '_',
#  'https://t.co/ZOZOSe1CqQ',
#  '#immigration',
#  '#integration',
#  '#canada',
#  'https://t.co/M5cKGyvV8F',
#  'We',
#  'want',
#  'controlled',
#  'immigration',
#  'that',
#  'contributes',
#  'positively',
#  'to',
#  'the',
#  'UK',
#  'economy',
#  '.',
#  'Same',
#  'as',
#  'Australia',
#  '&',
#  'Canada',
#  '.',
#  'https://t.co/99mYliuOes',
#  'Is',
#  'the',
#  'new',
#  'Manitoba',
#  'immigration',
#  'fee',
#  'a',
#  'head',
#  'tax',
#  '?',
#  'https://t.co/LsG7C3vLe9',
#  'Canada',
#  'immigration',
#  'profit',
#  'influence',
#  'modernistic',
#  'delhi',
#  'yet',
#  'abhinav',
#  ':',
#  'XKofy',
#  'https://t.co/becgusY2i6',
#  'Canada',
#  'Immigration',
#  'Minister',
#  'to',
#  '�',
#  '�',
#  '�',
#  'Substantially',
#  'Increase',
#  'Immigration',
#  'Numbers',
#  'https://t.co/nEFw30MRaa',
#  'https://t.co/cyI867PZRV',
#  'M',
#  '�',
#  '�',
#  'me',
#  'les',
#  '#USA',
#  '=p',
#  'ays',
#  "d'immigration",
#  'par',
#  'excellence',
#  'CONTR',
#  '�',
#  '�',
#  'LE',
#  'RIGOUREUSEMENT',
#  "l'immigration",
#  'et',
#  'acc',
#  '�',
#  '�',
#  's',
#  '�',
#  '�',
#  'la',
#  '#GreenCARD',
#  '!',
#  '�',
#  '�',
#  '_',
#  'https://t.co/IHpVhW2BaG',
#  'what',
#  'changes',
#  'should',
#  'be',
#  'made',
#  'to',
#  "Canada's",
#  'immigration',
#  'laws',
#  'due',
#  'to',
#  'the',
#  'influx',
#  'of',
#  'immigration',
#  'and',
#  'violence',
#  '?',
#  'L',
#  '�',
#  '�',
#  'immigration',
#  'irr',
#  '�',
#  '�',
#  'guli',
#  '�',
#  '�',
#  're',
#  'au',
#  'Canada',
#  'd',
#  '�',
#  '�',
#  'cortiqu',
#  '�',
#  '�',
#  'e',
#  'en',
#  '5',
#  'questions',
#  'https://t.co/f4utO5A7ZF',
#  "L'immigration",
#  'irr',
#  '�',
#  '�',
#  'guli',
#  '�',
#  '�',
#  're',
#  'au',
#  'Canada',
#  'd',
#  '�',
#  '�',
#  'cortiqu',
#  '�',
#  '�',
#  'e',
#  'en',
#  '5',
#  'questions',
#  '-',
#  'https://t.co/UiBsEZOqas',
#  'https://t.co/j77dEvjoiX',
#  'https://t.co/XXDeIG7Dbu',
#  'Will',
#  'Media',
#  'ask',
#  'the',
#  'Liberals',
#  'if',
#  'they',
#  'actually',
#  'have',
#  'a',
#  'solid',
#  'plan',
#  'for',
#  'Canada',
#  '_',
#  '�',
#  '�',
#  '_',
#  '�',
#  '_',
#  '?',
#  '?',
#  'From',
#  'my',
#  'view',
#  '-',
#  '-',
#  'immigration',
#  'out',
#  'of',
#  'C',
#  '�',
#  '�',
#  '_',
#  'https://t.co/YAgwmZ8ECp',
#  'Dan',
#  'Murray',
#  'of',
#  '�',
#  '�',
#  'Immigration',
#  'Watch',
#  'Canada',
#  'is',
#  'xenophobic',
#  'racist',
#  'fear-mongering',
#  'liar',
#  '#racism',
#  '#canada',
#  '#cdnpoli',
#  '#hatecrime',
#  '�',
#  '�',
#  '_',
#  'https://t.co/kwZ3csvYxM',
#  'Le',
#  'Canada',
#  'lance',
#  'une',
#  'vaste',
#  'campagne',
#  "d'immigration",
#  'pour',
#  'faire',
#  'face',
#  '�',
#  '�',
#  'son',
#  'besoin',
#  'de',
#  'main',
#  'd',
#  "'",
#  '�',
#  '�',
#  'uvre',
#  'https://t.co/kXdfMGTZzN',
#  'L',
#  '�',
#  '�',
#  '#immigration',
#  'irr',
#  '�',
#  '�',
#  'guli',
#  '�',
#  '�',
#  're',
#  'au',
#  '#Canada',
#  'd',
#  '�',
#  '�',
#  'cortiqu',
#  '�',
#  '�',
#  'e',
#  'en',
#  '5',
#  '�',
#  '�',
#  'questions',
#  'https://t.co/s3hu1OKKIG',
#  "I've",
#  'read',
#  'the',
#  'Immigration',
#  'laws',
#  'of',
#  'Canada',
#  'much',
#  'stricter',
#  'than',
#  'the',
#  'US',
#  'Canada',
#  'Immigration',
#  'Website',
#  'Traffic',
#  'Surges',
#  'And',
#  'Crashes',
#  'In',
#  'Wake',
#  'Of',
#  'Trump',
#  '#fasttraffic',
#  ',',
#  '#sitetraffic',
#  ',',
#  '#website',
#  ',',
#  '#traffic',
#  'https://t.co/zRlJ26jnkC',
#  'Mr',
#  'Know-all',
#  'of',
#  'Canada',
#  'Immigration',
#  'https://t.co/wTQK4QDiKI',
#  'Move',
#  'to',
#  'Canada',
#  'Oh',
#  ',',
#  'immigration',
#  'rules',
#  ',',
#  'you',
#  "can't",
#  '...',
#  'https://t.co/5LIEVHO7A4',
#  '#OnThisDay',
#  'Annette',
#  'Toft',
#  'becomes',
#  "Canada's",
#  '2',
#  'millionth',
#  'immigrant',
#  'since',
#  '1945',
#  '.',
#  'Do',
#  'you',
#  'know',
#  'your',
#  "family's",
#  'immigration',
#  'st',
#  '�',
#  '�',
#  '_',
#  'https://t.co/UvRuw8eR1b',
#  '.',
#  'profiles',
#  "Canada's",
#  'open',
#  'immigration',
#  'policies',
#  '&',
#  'how',
#  'they',
#  'contribute',
#  'to',
#  'our',
#  'economic',
#  'success',
#  ':',
#  '�',
#  '�',
#  '_',
#  'https://t.co/4K84EE8Y63',
#  'Hundreds',
#  'may',
#  'lose',
#  'Canadian',
#  'citizenship',
#  ',',
#  'resident',
#  'status',
#  'because',
#  'of',
#  'one',
#  'corrupt',
#  'immigration',
#  'consultant',
#  'https://t.co/x2IfO0EXI2',
#  'Immigration',
#  'for',
#  'canada',
#  'without',
#  'india',
#  ':',
#  'an',
#  'compassionate',
#  'handle',
#  ':',
#  'deyFy',
#  '"',
#  '#Jamaican',
#  '#immigrants',
#  '#Canada',
#  'https://t.co/vcmfYGadR5',
#  '#statistics',
#  '#immigration',
#  '"',
#  'Mexican',
#  'visa',
#  'lift',
#  'expected',
#  'to',
#  'cost',
#  'Canada',
#  '$',
#  '262M',
#  'over',
#  'a',
#  'decade',
#  'https://t.co/9i72fRhtij',
#  'Are',
#  'people',
#  'still',
#  'moving',
#  'to',
#  '#Canada',
#  '?',
#  '?',
#  '?',
#  'Oh',
#  "that's",
#  'right',
#  ',',
#  'they',
#  'have',
#  'real',
#  'immigration',
#  'laws',
#  'and',
#  "it's",
#  '�',
#  '�',
#  '_',
#  'https://t.co/0C5OBfmxLG',
#  'Here',
#  'are',
#  'more',
#  'details',
#  'on',
#  'the',
#  'Richmond',
#  ',',
#  'B',
#  '.',
#  'C',
#  '.',
#  'Immigration',
#  'Consultant',
#  'Sunny',
#  'Wang',
#  'who',
#  'was',
#  'sentenced',
#  'to',
#  '7',
#  'years',
#  'in',
#  '...',
#  'https://t.co/YXH5W53srO',
#  'I',
#  'added',
#  'a',
#  'video',
#  'to',
#  'a',
#  'playlist',
#  'https://t.co/CnEyWN40x3',
#  'Funny',
#  'Talking',
#  'of',
#  'Haryanavi',
#  'Jat',
#  'with',
#  'Canada',
#  'Immigration',
#  'Girl',
#  'Agent',
#  'Mexicans',
#  'Can',
#  'Now',
#  'Travel',
#  'Visa-Free',
#  'To',
#  'Canada',
#  'https://t.co/Ec3XHORO2s',
#  'https://t.co/RQRr5nebcG',
#  'L',
#  '�',
#  '�',
#  'immigration',
#  'irr',
#  '�',
#  '�',
#  'guli',
#  '�',
#  '�',
#  're',
#  'au',
#  'Canada',
#  'd',
#  '�',
#  '�',
#  'cortiqu',
#  '�',
#  '�',
#  'e',
#  'en',
#  '5',
#  '�',
#  '�',
#  'questions',
#  'https://t.co/DkpuKyWmaK',
#  'Hes',
#  'the',
#  'POS',
#  'that',
#  'ramped',
#  'up',
#  'immigration',
#  'for',
#  'Canada',
#  ',',
#  'among',
#  'other',
#  'globalist',
#  'policies',
#  '.',
#  'Canada',
#  'lifted',
#  'visa',
#  'requirements',
#  'to',
#  'Mexico',
#  'as',
#  'of',
#  'Dec',
#  '1',
#  ',',
#  '2016',
#  '.',
#  'Thoughts',
#  '?',
#  '#visa',
#  '#immigration',
#  'people',
#  'Keep',
#  'praising',
#  'Canada',
#  'and',
#  'Canada',
#  'has',
#  'way',
#  'stricter',
#  'immigration',
#  'laws',
#  'then',
#  'us',
#  'they',
#  'willl',
#  'boot',
#  'your',
#  'liberal',
#  'American',
#  'ass']

# %%
tokenized_research_paper
# Out:
# ['Neural',
#  'network',
#  'models',
#  'have',
#  'shown',
#  'their',
#  'promising',
#  'opportunities',
#  'for',
#  'multi-task',
#  'learning',
#  ',',
#  'which',
#  'focus',
#  'on',
#  'learning',
#  'the',
#  'shared',
#  'layers',
#  'to',
#  'extract',
#  'the',
#  'common',
#  'and',
#  'task-invariant',
#  'features',
#  '.',
#  'However',
#  ',',
#  'in',
#  'most',
#  'existing',
#  'approaches',
#  ',',
#  'the',
#  'extracted',
#  'shared',
#  'features',
#  'are',
#  'prone',
#  'to',
#  'be',
#  'contaminated',
#  'by',
#  'task-specific',
#  'features',
#  'or',
#  'the',
#  'noise',
#  'brought',
#  'by',
#  'other',
#  'tasks',
#  '.',
#  'In',
#  'this',
#  'paper',
#  ',',
#  'we',
#  'propose',
#  'an',
#  'adversarial',
#  'multi-task',
#  'learning',
#  'framework',
#  ',',
#  'alleviating',
#  'the',
#  'shared',
#  'and',
#  'private',
#  'latent',
#  'feature',
#  'spaces',
#  'from',
#  'interfering',
#  'with',
#  'each',
#  'other',
#  '.',
#  'We',
#  'conduct',
#  'extensive',
#  'experiments',
#  'on',
#  '16',
#  'different',
#  'text',
#  'classification',
#  'tasks',
#  ',',
#  'which',
#  'demonstrates',
#  'the',
#  'benefits',
#  'of',
#  'our',
#  'approach',
#  '.',
#  'Besides',
#  ',',
#  'we',
#  'show',
#  'that',
#  'the',
#  'shared',
#  'knowledge',
#  'learned',
#  'by',
#  'our',
#  'proposed',
#  'model',
#  'can',
#  'be',
#  'regarded',
#  'as',
#  'off-the-shelf',
#  'knowledge',
#  'and',
#  'easily',
#  'transferred',
#  'to',
#  'new',
#  'tasks',
#  '.',
#  'Multi-task',
#  'learning',
#  'is',
#  'an',
#  'effective',
#  'approach',
#  'to',
#  'improve',
#  'the',
#  'performance',
#  'of',
#  'a',
#  'single',
#  'task',
#  'with',
#  'the',
#  'help',
#  'of',
#  'other',
#  'related',
#  'tasks',
#  '.',
#  'Recently',
#  ',',
#  'neural-based',
#  'models',
#  'for',
#  'multi-task',
#  'learning',
#  'have',
#  'become',
#  'very',
#  'popular',
#  ',',
#  'ranging',
#  'from',
#  'computer',
#  'vision',
#  '(',
#  'Misra',
#  'et',
#  'al',
#  '.',
#  ',',
#  '2016',
#  ';',
#  'Zhang',
#  'et',
#  'al',
#  '.',
#  ',',
#  '2014',
#  ')',
#  'to',
#  'natural',
#  'language',
#  'processing',
#  '(',
#  'Collobert',
#  'andWeston',
#  ',',
#  '2008',
#  ';',
#  'Luong',
#  'et',
#  'al',
#  '.',
#  ',',
#  '2015',
#  ')',
#  ',',
#  'since',
#  'they',
#  'provide',
#  'a',
#  'convenient',
#  'way',
#  'of',
#  'combining',
#  'information',
#  'from',
#  'multiple',
#  'tasks',
#  '.',
#  'However',
#  ',',
#  'most',
#  'existing',
#  'work',
#  'on',
#  'multi-task',
#  'learning',
#  '(',
#  'Liu',
#  'et',
#  'al',
#  '.',
#  ',',
#  '2016c',
#  ',',
#  'b',
#  ')',
#  'attempts',
#  'to',
#  'divide',
#  'the',
#  'features',
#  'of',
#  'different',
#  'tasks',
#  'into',
#  'private',
#  'and',
#  'shared',
#  'spaces',
#  ',',
#  'merely',
#  'based',
#  'on',
#  'whether',
#  'parameters',
#  'of',
#  'some',
#  'components',
#  'should',
#  'be',
#  'shared',
#  '.',
#  'As',
#  'shown',
#  'in',
#  'Figure',
#  '1',
#  '-',
#  '(',
#  'a',
#  ')',
#  ',',
#  'the',
#  'general',
#  'shared-private',
#  'model',
#  'introduces',
#  'two',
#  'feature',
#  'spaces',
#  'for',
#  'any',
#  'task',
#  ':',
#  'one',
#  'is',
#  'used',
#  'to',
#  'store',
#  'task-dependent',
#  'features',
#  ',',
#  'the',
#  'other',
#  'is',
#  'used',
#  'to',
#  'capture',
#  'shared',
#  'features',
#  '.',
#  'The',
#  'major',
#  'limitation',
#  'of',
#  'this',
#  'framework',
#  'is',
#  'that',
#  'the',
#  'shared',
#  'feature',
#  'space',
#  'could',
#  'contain',
#  'some',
#  'unnecessary',
#  'task-specific',
#  'features',
#  ',',
#  'while',
#  'some',
#  'sharable',
#  'features',
#  'could',
#  'also',
#  'be',
#  'mixed',
#  'in',
#  'private',
#  'space',
#  ',',
#  'suffering',
#  'from',
#  'feature',
#  'redundancy',
#  '.',
#  'Taking',
#  'the',
#  'following',
#  'two',
#  'sentences',
#  'as',
#  'examples',
#  ',',
#  'which',
#  'are',
#  'extracted',
#  'from',
#  'two',
#  'different',
#  'sentiment',
#  'classification',
#  'tasks',
#  ':',
#  'Movie',
#  'reviews',
#  'and',
#  'Baby',
#  'products',
#  'reviews',
#  '.',
#  'The',
#  'infantile',
#  'cart',
#  'is',
#  'simple',
#  'and',
#  'easy',
#  'to',
#  'use',
#  '.',
#  'This',
#  'kind',
#  'of',
#  'humour',
#  'is',
#  'infantile',
#  'and',
#  'boring',
#  '.',
#  'The',
#  'word',
#  '�',
#  'infantile',
#  '�',
#  'indicates',
#  'negative',
#  'sentiment',
#  'in',
#  'Movie',
#  'task',
#  'while',
#  'it',
#  'is',
#  'neutral',
#  'in',
#  'Baby',
#  'task',
#  '.',
#  'However',
#  ',',
#  'the',
#  'general',
#  'shared-private',
#  'model',
#  'could',
#  'place',
#  'the',
#  'task-specific',
#  'word',
#  '�',
#  'infantile',
#  '�',
#  'in',
#  'a',
#  'shared',
#  'space',
#  ',',
#  'leaving',
#  'potential',
#  'hazards',
#  'for',
#  'other',
#  'tasks',
#  '.',
#  'Additionally',
#  ',',
#  'the',
#  'capacity',
#  'of',
#  'shared',
#  'space',
#  'could',
#  'also',
#  'be',
#  'wasted',
#  'by',
#  'some',
#  'unnecessary',
#  'features',
#  '.',
#  'To',
#  'address',
#  'this',
#  'problem',
#  ',',
#  'in',
#  'this',
#  'paper',
#  'we',
#  'propose',
#  'an',
#  'adversarial',
#  'multi-task',
#  'framework',
#  ',',
#  'in',
#  'which',
#  'the',
#  'shared',
#  'and',
#  'private',
#  'feature',
#  'spaces',
#  'are',
#  'in',
#  'herently',
#  'disjoint',
#  'by',
#  'introducing',
#  'orthogonality',
#  'constraints.Specifically',
#  ',',
#  'we',
#  'design',
#  'a',
#  'generic',
#  'shared',
#  'private',
#  'learning',
#  'framework',
#  'to',
#  'model',
#  'the',
#  'text',
#  'sequence',
#  '.']

# %% [markdown]
# Question 02: Context Sensitive Word Correction

# %%
# !pip install neuspell
# Out:
# Requirement already satisfied: neuspell in /usr/local/lib/python3.7/dist-packages (1.0.0)
# Requirement already satisfied: jsonlines in /usr/local/lib/python3.7/dist-packages (from neuspell) (2.0.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from neuspell) (1.9.0+cu111)
# Requirement already satisfied: pytorch-pretrained-bert in /usr/local/lib/python3.7/dist-packages (from neuspell) (0.6.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (from neuspell) (4.11.3)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from neuspell) (0.1.96)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from neuspell) (4.62.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from neuspell) (1.19.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->neuspell) (3.7.4.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from pytorch-pretrained-bert->neuspell) (2.23.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from pytorch-pretrained-bert->neuspell) (2019.12.20)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.7/dist-packages (from pytorch-pretrained-bert->neuspell) (1.18.60)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from boto3->pytorch-pretrained-bert->neuspell) (0.5.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from boto3->pytorch-pretrained-bert->neuspell) (0.10.0)
# Requirement already satisfied: botocore<1.22.0,>=1.21.60 in /usr/local/lib/python3.7/dist-packages (from boto3->pytorch-pretrained-bert->neuspell) (1.21.60)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.7/dist-packages (from botocore<1.22.0,>=1.21.60->boto3->pytorch-pretrained-bert->neuspell) (1.25.11)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.22.0,>=1.21.60->boto3->pytorch-pretrained-bert->neuspell) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.22.0,>=1.21.60->boto3->pytorch-pretrained-bert->neuspell) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->pytorch-pretrained-bert->neuspell) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->pytorch-pretrained-bert->neuspell) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->pytorch-pretrained-bert->neuspell) (2021.5.30)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers->neuspell) (4.8.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers->neuspell) (21.0)
# Requirement already satisfied: huggingface-hub>=0.0.17 in /usr/local/lib/python3.7/dist-packages (from transformers->neuspell) (0.0.19)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers->neuspell) (3.3.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers->neuspell) (5.4.1)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers->neuspell) (0.0.46)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers->neuspell) (0.10.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers->neuspell) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers->neuspell) (3.6.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers->neuspell) (1.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers->neuspell) (7.1.2)

# %%
from neuspell import CnnlstmChecker

# %%
checker = CnnlstmChecker()
checker.from_pretrained()
# Out:
# loading vocab from path:/usr/local/lib/python3.7/dist-packages/neuspell/../data/checkpoints/cnn-lstm-probwordnoise/vocab.pkl
# initializing model
# CharCNNWordLSTMModel(
#   (cnnmodule): CharCNNModel(
#     (embeddings): Embedding(98, 100, padding_idx=1)
#     (convmodule): ModuleList(
#       (0): Sequential(
#         (0): Conv2d(1, 50, kernel_size=(2, 100), stride=(1, 1), padding=(1, 0))
#         (1): ReLU()
#       )
#       (1): Sequential(
#         (0): Conv2d(1, 100, kernel_size=(3, 100), stride=(1, 1), padding=(2, 0))
#         (1): ReLU()
#       )
#       (2): Sequential(
#         (0): Conv2d(1, 100, kernel_size=(4, 100), stride=(1, 1), padding=(3, 0))
#         (1): ReLU()
#       )
#       (3): Sequential(
#         (0): Conv2d(1, 100, kernel_size=(5, 100), stride=(1, 1), padding=(4, 0))
#         (1): ReLU()
#       )
#     )
#   )
#   (lstmmodule): LSTM(350, 512, num_layers=2, batch_first=True, dropout=0.3, bidirectional=True)
#   (dropout): Dropout(p=0.4, inplace=False)
#   (dense): Linear(in_features=1024, out_features=100002, bias=True)
#   (criterion): CrossEntropyLoss()
# )
# 112480792
# loading pretrained weights from path:/usr/local/lib/python3.7/dist-packages/neuspell/../data/checkpoints/cnn-lstm-probwordnoise
# Loading model params from checkpoint dir: /usr/local/lib/python3.7/dist-packages/neuspell/../data/checkpoints/cnn-lstm-probwordnoise

# %% [markdown]
# Context Sensitive Spell Correction: Research Paper

# %%
print("============ Before spell correction ================") 
print(research_paper)
print("###################################################\n")

print("=========== After spell correction===================")
spell_corrected_research_paper = checker.correct_strings([research_paper])
print(spell_corrected_research_paper[0])
# Out:
# ============ Before spell correction ================
# Neural network models have shown their promising opportunities for multi-task
# learning, which focus on learning the shared layers to extract the common and
# task-invariant features. However, in most existing approaches, the extracted shared
# features are prone to be contaminated by task-specific features or the noise brought
# by other tasks. In this paper, we propose an adversarial multi-task learning framework,
# alleviating the shared and private latent feature spaces from interfering with
# each other. We conduct extensive experiments on 16 different text classification
# tasks, which demonstrates the benefits of our approach. Besides, we show that the
# shared knowledge learned by our proposed model can be regarded as off-the-shelf
# knowledge and easily transferred to new tasks.
#
# Multi-task learning is an effective approach to improve the performance of a single task with
# the help of other related tasks. Recently, neural-based models for multi-task learning have become
# very popular, ranging from computer vision (Misra et al., 2016; Zhang et al., 2014) to natural
# language processing (Collobert andWeston, 2008; Luong et al., 2015), since they provide a convenient
# way of combining information from multiple tasks.
# However, most existing work on multi-task learning (Liu et al., 2016c,b) attempts to divide the
# features of different tasks into private and shared spaces, merely based on whether parameters of some components should be shared. As shown in Figure 1-(a), the general shared-private model introduces
# two feature spaces for any task: one is used to store task-dependent features, the other is
# used to capture shared features. The major limitation of this framework is that the shared feature
# space could contain some unnecessary task-specific features, while some sharable features
# could also be mixed in private space, suffering from feature redundancy.
# Taking the following two sentences as examples, which are extracted from two different sentiment
# classification tasks: Movie reviews and Baby products reviews.
# The infantile cart is simple and easy to use. This kind of humour is infantile and boring.
# The word �infantile� indicates negative sentiment in Movie task while it is neutral in Baby task.
# However, the general shared-private model could place the task-specific word �infantile� in a
# shared space, leaving potential hazards for other tasks. Additionally, the capacity of shared space
# could also be wasted by some unnecessary features.
# To address this problem, in this paper we propose an adversarial multi-task framework, in
# which the shared and private feature spaces are in herently disjoint by introducing orthogonality constraints.Specifically, we design a generic shared private learning framework to model the text sequence.
# ###################################################
#
# =========== After spell correction===================
# ###############################################
# data size: 1
# 1it [00:09,  9.08s/it]
# total inference time for this data is: 9.088116 secs
# Natural network models have shown their promising opportunities for multi - task learning , which focus on learning the shared layers to extract the common and task - invariant features . However , in most existing approaches , the extracted shared features are prone to be contaminated by task - specific features or the noise brought by other tasks . In this paper , we propose an adversary multi - task learning framework , alleviating the shared and private latent feature spaces from interfering with each other . We conduct extensive experiments on 16 different text classification tasks , which demonstrates the benefits of our approach . Besides , we show that the shared knowledge learned by our proposed model can be regarded as off - then - shelf knowledge and easily transferred to new tasks . Multi - task learning is an effective approach to improve the performance of a single task with the help of other related tasks . Recently , neural - based models for multi - task learning have become very popular , ranging from computer vision ( Misra et al .. 2016 ; Zhang et al .. 2014 ) to natural language processing ( Collobert andWeston , 2008 ; Luong et al .. 2015 ) since they provide a convenient way of combining information from multiple tasks . However , most existing work on multi - task learning ( Liu et al .. 2016c , b ) attempts to divide the features of different tasks into private and shared spaces , merely based on whether parameters of some components should be shared . As shown in Figure 1-(a , the general shared - private model introduces to feature spaces for any task : one is used to store task - dependent features , the other is used to capture shared features . The major limitation of this framework is that the shared feature space could contain some unnecessary task - specific features , while some charitable features could also be mixed in private space , suffering from feature redundancy . Taking the following two sentences as examples , which are extracted from two different sentiment classification tasks : Movie reviews and Baby products reviews . The infantile card is simple and easy to use . This kind of humour is intangible and boring . The word and intangible and indicates negative sentiment in Movie task while it is neutral in Baby task . However , the general shared - private model could place the task - specific word and intangible and in a shared space , leaving potential hazards for other tasks . Additionally , the capacity of shared space could also be wasted by some unnecessary features . To address this problem , in this paper we propose an adversary multi - task framework , in which the shared and private feature spaces are in inherently discount by introducing orthogonality constraints . Specifically , we design a generic shared private learning framework to model the text sequence .

# %% [markdown]
# Context Sensitive Spell Correction: Twitter

# %%
print("============ Before spell correction ================") 
print(twitter)

print("###################################################\n")
print("=========== After spell correction===================")
spell_corrected_twitter = checker.correct_strings([twitter])
print(spell_corrected_twitter[0])
# Out:
# ============ Before spell correction ================
#
# Reminds me of Liberal Immigration Fraudster Monsef avoiding deportation from Canada. #cdnpoli #LPC #CPCLDR��_ https://t.co/ZOZOSe1CqQ
# #immigration #integration #canada https://t.co/M5cKGyvV8F
# We want controlled immigration that contributes positively to the UK economy. Same as Australia &amp; Canada. https://t.co/99mYliuOes
# Is the new Manitoba immigration fee a head tax? https://t.co/LsG7C3vLe9
# Canada immigration profit influence modernistic delhi yet abhinav: XKofy https://t.co/becgusY2i6
# Canada Immigration Minister to ���Substantially Increase  Immigration Numbers https://t.co/nEFw30MRaa https://t.co/cyI867PZRV
# M��me les #USA=pays d'immigration par excellence CONTR��LE RIGOUREUSEMENT l'immigration et acc��s �� la #GreenCARD!��_ https://t.co/IHpVhW2BaG
# @Shawhelp what changes should be made to Canada's immigration laws due to the influx of immigration and violence?
# L��immigration irr��guli��re au Canada d��cortiqu��e en 5 questions https://t.co/f4utO5A7ZF
# L'immigration irr��guli��re au Canada d��cortiqu��e en 5 questions - https://t.co/UiBsEZOqas https://t.co/j77dEvjoiX https://t.co/XXDeIG7Dbu
# Will Media ask the Liberals if they actually have a solid plan for Canada _��_�_?? From my view -- immigration out of C��_ https://t.co/YAgwmZ8ECp
# Dan Murray of��Immigration Watch Canada is xenophobic racist fear-mongering liar #racism #canada #cdnpoli #hatecrime��_ https://t.co/kwZ3csvYxM
# Le Canada lance une vaste campagne d'immigration pour faire face �� son besoin de main d'��uvre https://t.co/kXdfMGTZzN
# L��#immigration irr��guli��re au #Canada d��cortiqu��e en 5��questions https://t.co/s3hu1OKKIG
# @Canadidly I've read the Immigration laws of Canada much stricter than the US
# Canada Immigration Website Traffic Surges And Crashes In Wake Of Trump #fasttraffic,#sitetraffic,#website,#traffic https://t.co/zRlJ26jnkC
# Mr Know-all of Canada Immigration https://t.co/wTQK4QDiKI
# Move to Canada @LadyMadonna___ Oh, immigration rules, you can't... https://t.co/5LIEVHO7A4
# #OnThisDay Annette Toft becomes Canada's 2 millionth immigrant since 1945. Do you know your family's immigration st��_ https://t.co/UvRuw8eR1b
# .@TheEconomist profiles Canada's open immigration policies &amp; how they contribute to our economic success:��_ https://t.co/4K84EE8Y63
# Hundreds may lose Canadian citizenship, resident status because of one corrupt immigration consultant https://t.co/x2IfO0EXI2
# Immigration for canada without india: an compassionate handle: deyFy
# "#Jamaican #immigrants #Canada
#
# https://t.co/vcmfYGadR5
#
# #statistics #immigration"
# Mexican visa lift expected to cost Canada $262M over a decade https://t.co/9i72fRhtij
# Are people still moving to #Canada ??? Oh that's right, they have real immigration laws and it's��_ https://t.co/0C5OBfmxLG
# Here are more details on the Richmond, B.C. Immigration Consultant Sunny Wang who was sentenced to 7 years in... https://t.co/YXH5W53srO
# I added a video to a @YouTube playlist https://t.co/CnEyWN40x3 Funny Talking of Haryanavi Jat with Canada Immigration Girl Agent
# Mexicans Can Now Travel Visa-Free To Canada https://t.co/Ec3XHORO2s https://t.co/RQRr5nebcG
# L��immigration irr��guli��re au Canada d��cortiqu��e en 5��questions https://t.co/DkpuKyWmaK
# @SweetnessShawnB Hes the POS that ramped up immigration for Canada, among other globalist policies.
# Canada lifted visa requirements to Mexico as of Dec 1, 2016. Thoughts? #visa #immigration
# @HuffingtonPost people Keep praising Canada and Canada has way stricter immigration laws then us they willl boot your liberal American ass
# ###################################################
#
# =========== After spell correction===================
# ###############################################
# data size: 1
# 1it [00:10, 10.28s/it]
# total inference time for this data is: 10.298662 secs
# Reminds me of Liberal Immigration Fraudster Monsef avoiding deportation from Canada .# cdnpoli # LPC # CPCLDR and and _ https://t.co/ZOZOSe1CqQ # immigration # integration # canada https://t.co/M5cKGyvV8F We want controlled immigration that contributes positively to the UK economy . Same as Australia & amp ; Canada . https://t.co/99mYliuOes Is the new Manitoba immigration fee a head tax ? https://t.co/LsG7C3vLe9 Canada immigration profit influence modernistic delhi yet abhinav : XKofy https://t.co/becgusY2i6 Canada Immigration Minister to end and and Substantially Increase Immigration Numbers https://t.co/nEFw30MRaa https://t.co/cyI867PZRV M and and the les # USA = pays immigration for excellence CONTR and and LE RIGOUREUSEMENT immigration et acc and and s and and la # GreenCARD ! and and _ https://t.co/IHpVhW2BaG @Shawhelp what changes should be made to Canada 's immigration laws due to the influx of immigration and violence ? L and and immigration air and and guli and and re at Canada d and and cortiqu and and and in 5 questions https://t.co/f4utO5A7ZF L'immigration or and and guli and and re at Canada d and and cortiqu and and and in 5 questions - https://t.co/UiBsEZOqas https://t.co/j77dEvjoiX https://t.co/XXDeIG7Dbu Will Media ask the Liberals if they actually have a solid plan for Canada _ and and _ and _?? From my view -- immigration out of C and and _ https://t.co/YAgwmZ8ECp Dan Murray of and and Immigration Watch Canada is xenophobic racist fear - mongering liar # racism # canada # cdnpoli # hatecrime and and _ https://t.co/kwZ3csvYxM Le Canada lance one vast campaign emigration pour fair face and and son behind the main d' and and uvre https://t.co/kXdfMGTZzN L y y #immigration or and and guli and and re au # Canada d and and cortiqu and and e in 5 and and questions https://t.co/s3hu1OKKIG @Canadidly I 've read the Immigration laws of Canada much stricter than the US Canada Immigration Website Traffic Surges And Crashers In Wake Of Trump # fasttraffic,#sitetraffic,#website,#traffic https://t.co/zRlJ26jnkC Mr Know - all of Canada Immigration https://t.co/wTQK4QDiKI Move to Canada @LadyMadonna ___ Oh , immigration rules , you can not ... https://t.co/5LIEVHO7A4 # OnThisDay Annette Toft becomes Canada 's 2 millionth immigrant since 1945 . Do you know your family 's immigration in and and _ https://t.co/UvRuw8eR1b .@TheEconomist profiles Canada 's open immigration policies & amp ; how they contribute to our economic success : and and _ https://t.co/4K84EE8Y63 Hundreds may lose Canadian citizenship , resident status because of the corrupt immigration consultant https://t.co/x2IfO0EXI2 Immigration for canada without indie : an compassionate handle : deyFy "# Jamaican # immigrants # Canada https://t.co/vcmfYGadR5 # statistics # immigration " Mexican visa lift expected to cost Canada $ 262 M over a decade https://t.co/9i72fRhtij Are people still moving to # Canada ... Oh that 's right , they have real immigration laws and it 's and and _ https://t.co/0C5OBfmxLG Here are more details on the Richmond , B.C. Immigration Consultant Sunny Wang who was sentenced to 7 years in ... https://t.co/YXH5W53srO I added a video to a YouTube playlist https://t.co/CnEyWN40x3 Funny Talking of Haryanavi Jet with Canada Immigration Girl Agent Mexicans Can Now Travel Visa - Free To Canada https://t.co/Ec3XHORO2s https://t.co/RQRr5nebcG L and and immigration air and and guile and and re at Canada d and and cortiqu and and and in 5 and and questions https://t.co/DkpuKyWmaK @SweetnessShawnB He 's the POS that ramped up immigration for Canada , among other globalist policies . Canada lifted visa requirements to Mexico as of Dec 1 , 2016 . Thoughts ?# visa # immigration @HuffingtonPost people Keep praising Canada and Canada has way stricter immigration laws than us they will boot your liberal American as

# %% [markdown]
# Context Sensitive Spell Correction: Student Feedback

# %%
print("============ Before spell correction ================") 
print(student_feedback)
print("###################################################\n")

print("=========== After spell correction===================")
spell_corrected_student_feedback = checker.correct_strings([student_feedback ])
print(spell_corrected_student_feedback[0])
# Out:
# ============ Before spell correction ================
# Honestly last seven lectures are good. Lectures are understandable. Lecture slides are very useful to self-study also. The given opportunity to ask questions from the lecturer is appreciative.
# "Good :)
# <br />please do recap at class starting it&#039;s better for us.
# <br />sometimes teaching speed is very high.
# <br />
# <br />Thanks ! :)
# <br /> "
# The lectures are good..but a bit speed.A in class working activity is a must one.So please take another hour in thursdays madame.
# "
# <br />We can hear your voice clearly and can understand the things you teach. Presentation slides also good source to refer . lf you can do more example questions within the classroom and it will help us to understand the principles well.
# <br />"
# Lectures was well structured and well organized. It was easy to understand. Lecture slides and labs were also well organized.
# Lectures were good. understandable.
# The lecture slides were well organized and the examples done in the class helped a lot to learn this new language and also the principles of OOP. Motivated to well. Would have been better if we discussed more about the solutions of coding exercisers.
# I think i learned a lot from the codes you write in the board. When i compare my codes with yours i can learn about my mistakes and good coding practices that i should follow. There fore i think it would be great if we can discuss more examples in the class.
# madam explained  the oop concepts clearly with examples.lectures were interesting.we want more scenario examples and answers with explanations in future.
# I satisfy about first 7 lectures. That way of teaching is really good for coming lectures too.
# lectuers are very good. take good effort to make undersatand every student in the room. very helpfull.
# I was able to obtain a clear picture about OOP and its concepts.
# "lecture slides, explanations were very clear.
# <br />it&#039;s very good to letting ask questions and explain again with suitable examples.
# <br />sometimes, some codes on white board were unclear at the back.
# <br />overall very good!!!
# <br />"
# The lectures were good and clear. And they weren&#039;t too fast. Writing code was somewhat confusing because I didn&#039;t know java before.
# Actually teaching is very good and can understand easily the concepts by examples which are given in the class.it will be more helpful if provide solved questions as well!. thankyou
# ###################################################
#
# =========== After spell correction===================
# ###############################################
# data size: 1
# 1it [00:07,  7.81s/it]
# total inference time for this data is: 7.818230 secs
# Honestly last seven lectures are good . Lecturers are understandable . Lecture slides are very useful to self - study also . The given opportunity to ask questions from the lecturer is appreciative . " Good ) < or />please to recap at class starting it&#039;s better for us . < or />sometimes teaching speed is very high . < or > < or />Thanks !:) < or />" The lectures are good .. but a bit speed . A in class working activity is a must one . So please take another hour in Thursdays manmade . " < or />We can hear your voice clearly and can understand the things you teach . Presentation slides also good source to refer . if you can do more example questions within the classroom and it will help us to understand the principles well . < or />" Lecturers was well structured and well organized . It was easy to understand . Lecture slides and labs were also well organized . Lectures were good . understandable . The lecture slides were well organized and the examples done in the class helped a lot to learn this new language and also the principles of OOP . Motivated too well . Would have been better if we discussed more about the solutions of coding exercises . I think i learned a lot from the codes you write in the board . When i compare my codes with yours i can learn about my mistakes and good coding practices that it should follow . There for i think it would be great if we can discuss more examples in the class . madam explained the top concepts clearly with examples.lectures were interesting.we want more scenario examples and answers with explanations in future . I satisfy about first 7 lectures . That way of teaching is really good for coming lectures too . lecturers are very good . take good effort to make understand every student in the room . very helpful . I was able to obtain a clear picture about OOP and its concepts . " lecture slides , explanations were very clear . < or />it&#039;s very good to letting ask questions and explain again with suitable examples . < or />sometimes , some codes on white board were unclear at the back . < or />overall very good . < or />" The lectures were good and clear . And they weren&#039;t too fast . Writing code was somewhat confusing because I didn&#039;t no have before . Actually teaching is very good and can understand easily the concepts by examples which are given in the class.it will be more helpful if provide solved questions as well .. thankyou

# %% [markdown]
# Isolated spell correction: Jaccard Distance

# %%
import nltk
import re
import string
from nltk.metrics.distance  import jaccard_distance
from nltk.util import ngrams
nltk.download('words')
from nltk.corpus import words
correct_words = words.words()

def correctSpellingInText(text):

  preprocessedWords = []

  for word in text:
    #remove HTML tags
    html_tags = re.compile('<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});')
    cleantext = re.sub(html_tags, '', word)

    #replace punctuation marks by space
    regular_punct = list(string.punctuation)
    for punc in regular_punct:
          if punc in cleantext:
              cleantext = cleantext.replace(punc, '')

    preprocessedWords.append(cleantext)

  
  print("preprocessedWords", preprocessedWords)
  print("cleantext",cleantext)

  spellCorrectedText = ""

  for word in preprocessedWords:
    if(len(word)>1 and not(word.isnumeric())):
      temp = [(jaccard_distance(set(ngrams(word, 2)),
                              set(ngrams(w, 2))),w)
            for w in correct_words if w[0]==word[0]]
      print(word + " -> " + sorted(temp, key = lambda val:val[0])[0][1])
      spellCorrectedText = spellCorrectedText + " " + sorted(temp, key = lambda val:val[0])[0][1]
    else:
      spellCorrectedText = spellCorrectedText + " " + word

  print(spellCorrectedText)

  return spellCorrectedText
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
correctSpellingInText(tokenized_student_feedback)
# Out:
# preprocessedWords ['Honestly', 'last', 'seven', 'lectures', 'are', 'good', '', 'Lectures', 'are', 'understandable', '', 'Lecture', 'slides', 'are', 'very', 'useful', 'to', 'selfstudy', 'also', '', 'The', 'given', 'opportunity', 'to', 'ask', 'questions', 'from', 'the', 'lecturer', 'is', 'appreciative', '', '', 'Good', '', '', 'br', '', '', 'please', 'do', 'recap', 'at', 'class', 'starting', 'its', 'better', 'for', 'us', '', '', 'br', '', '', 'sometimes', 'teaching', 'speed', 'is', 'very', 'high', '', '', 'br', '', '', '', 'br', '', '', 'Thanks', '', '', '', 'br', '', '', '', 'The', 'lectures', 'are', 'good', '', 'but', 'a', 'bit', 'speed', '', 'A', 'in', 'class', 'working', 'activity', 'is', 'a', 'must', 'oneSo', 'please', 'take', 'another', 'hour', 'in', 'thursdays', 'madame', '', '', '', 'br', '', '', 'We', 'can', 'hear', 'your', 'voice', 'clearly', 'and', 'can', 'understand', 'the', 'things', 'you', 'teach', '', 'Presentation', 'slides', 'also', 'good', 'source', 'to', 'refer', '', 'lf', 'you', 'can', 'do', 'more', 'example', 'questions', 'within', 'the', 'classroom', 'and', 'it', 'will', 'help', 'us', 'to', 'understand', 'the', 'principles', 'well', '', '', 'br', '', '', '', 'Lectures', 'was', 'well', 'structured', 'and', 'well', 'organized', '', 'It', 'was', 'easy', 'to', 'understand', '', 'Lecture', 'slides', 'and', 'labs', 'were', 'also', 'well', 'organized', '', 'Lectures', 'were', 'good', '', 'understandable', '', 'The', 'lecture', 'slides', 'were', 'well', 'organized', 'and', 'the', 'examples', 'done', 'in', 'the', 'class', 'helped', 'a', 'lot', 'to', 'learn', 'this', 'new', 'language', 'and', 'also', 'the', 'principles', 'of', 'OOP', '', 'Motivated', 'to', 'well', '', 'Would', 'have', 'been', 'better', 'if', 'we', 'discussed', 'more', 'about', 'the', 'solutions', 'of', 'coding', 'exercisers', '', 'I', 'think', 'i', 'learned', 'a', 'lot', 'from', 'the', 'codes', 'you', 'write', 'in', 'the', 'board', '', 'When', 'i', 'compare', 'my', 'codes', 'with', 'yours', 'i', 'can', 'learn', 'about', 'my', 'mistakes', 'and', 'good', 'coding', 'practices', 'that', 'i', 'should', 'follow', '', 'There', 'fore', 'i', 'think', 'it', 'would', 'be', 'great', 'if', 'we', 'can', 'discuss', 'more', 'examples', 'in', 'the', 'class', '', 'madam', 'explained', 'the', 'oop', 'concepts', 'clearly', 'with', 'exampleslectures', 'were', 'interestingwe', 'want', 'more', 'scenario', 'examples', 'and', 'answers', 'with', 'explanations', 'in', 'future', '', 'I', 'satisfy', 'about', 'first', '7', 'lectures', '', 'That', 'way', 'of', 'teaching', 'is', 'really', 'good', 'for', 'coming', 'lectures', 'too', '', 'lectuers', 'are', 'very', 'good', '', 'take', 'good', 'effort', 'to', 'make', 'undersatand', 'every', 'student', 'in', 'the', 'room', '', 'very', 'helpfull', '', 'I', 'was', 'able', 'to', 'obtain', 'a', 'clear', 'picture', 'about', 'OOP', 'and', 'its', 'concepts', '', '', 'lecture', 'slides', '', 'explanations', 'were', 'very', 'clear', '', '', 'br', '', '', 'its', 'very', 'good', 'to', 'letting', 'ask', 'questions', 'and', 'explain', 'again', 'with', 'suitable', 'examples', '', '', 'br', '', '', 'sometimes', '', 'some', 'codes', 'on', 'white', 'board', 'were', 'unclear', 'at', 'the', 'back', '', '', 'br', '', '', 'overall', 'very', 'good', '', '', '', '', 'br', '', '', '', 'The', 'lectures', 'were', 'good', 'and', 'clear', '', 'And', 'they', 'werent', 'too', 'fast', '', 'Writing', 'code', 'was', 'somewhat', 'confusing', 'because', 'I', 'didnt', 'know', 'java', 'before', '', 'Actually', 'teaching', 'is', 'very', 'good', 'and', 'can', 'understand', 'easily', 'the', 'concepts', 'by', 'examples', 'which', 'are', 'given', 'in', 'the', 'classit', 'will', 'be', 'more', 'helpful', 'if', 'provide', 'solved', 'questions', 'as', 'well', '', '', 'thankyou']
# cleantext thankyou
# Honestly -> Hesione
# last -> last
# seven -> seven
# lectures -> lecturess
# are -> are
# good -> good
# Lectures -> Les
# are -> are
# understandable -> understandable
# Lecture -> Latrodectus
# slides -> slide
# are -> are
# very -> very
# useful -> useful
# to -> to
# selfstudy -> study
# also -> also
# The -> The
# given -> given
# opportunity -> opportunity
# to -> to
# ask -> ask
# questions -> question
# from -> from
# the -> the
# lecturer -> lecturer
# is -> is
# appreciative -> appreciative
# Good -> God
# br -> bra
# please -> please
# do -> do
# recap -> recap
# at -> at
# class -> class
# starting -> starting
# its -> its
# better -> better
# for -> for
# us -> us
# br -> bra
# sometimes -> sometimes
# teaching -> teaching
# speed -> speed
# is -> is
# very -> very
# high -> high
# br -> bra
# br -> bra
# Thanks -> Thalian
# br -> bra
# The -> The
# lectures -> lecturess
# are -> are
# good -> good
# but -> but
# bit -> bit
# speed -> speed
# in -> in
# class -> class
# working -> working
# activity -> activity
# is -> is
# must -> must
# oneSo -> one
# please -> please
# take -> take
# another -> another
# hour -> hour
# in -> in
# thursdays -> thurse
# madame -> madame
# br -> bra
# We -> Wea
# can -> can
# hear -> hear
# your -> your
# voice -> voice
# clearly -> clearly
# and -> and
# can -> can
# understand -> understand
# the -> the
# things -> thing
# you -> you
# teach -> teach
# Presentation -> Predentata
# slides -> slide
# also -> also
# good -> good
# source -> source
# to -> to
# refer -> refer
# lf -> l
# you -> you
# can -> can
# do -> do
# more -> more
# example -> example
# questions -> question
# within -> within
# the -> the
# classroom -> classroom
# and -> and
# it -> it
# will -> will
# help -> help
# us -> us
# to -> to
# understand -> understand
# the -> the
# principles -> principle
# well -> well
# br -> bra
# Lectures -> Les
# was -> was
# well -> well
# structured -> structured
# and -> and
# well -> well
# organized -> organized
# It -> Ita
# was -> was
# easy -> easy
# to -> to
# understand -> understand
# Lecture -> Latrodectus
# slides -> slide
# and -> and
# labs -> lab
# were -> were
# also -> also
# well -> well
# organized -> organized
# Lectures -> Les
# were -> were
# good -> good
# understandable -> understandable
# The -> The
# lecture -> lecture
# slides -> slide
# were -> were
# well -> well
# organized -> organized
# and -> and
# the -> the
# examples -> example
# done -> done
# in -> in
# the -> the
# class -> class
# helped -> helper
# lot -> lot
# to -> to
# learn -> learn
# this -> this
# new -> new
# language -> language
# and -> and
# also -> also
# the -> the
# principles -> principle
# of -> of
# OOP -> O
# Motivated -> Morcote
# to -> to
# well -> well
# Would -> Wogulian
# have -> have
# been -> been
# better -> better
# if -> if
# we -> we
# discussed -> discusser
# more -> more
# about -> about
# the -> the
# solutions -> solution
# of -> of
# coding -> codding
# exercisers -> exercise
# think -> think
# learned -> learned
# lot -> lot
# from -> from
# the -> the
# codes -> code
# you -> you
# write -> write
# in -> in
# the -> the
# board -> board
# When -> Wend
# compare -> compare
# my -> my
# codes -> code
# with -> with
# yours -> yours
# can -> can
# learn -> learn
# about -> about
# my -> my
# mistakes -> mistake
# and -> and
# good -> good
# coding -> codding
# practices -> practice
# that -> that
# should -> should
# follow -> follow
# There -> Theresa
# fore -> fore
# think -> think
# it -> it
# would -> would
# be -> be
# great -> great
# if -> if
# we -> we
# can -> can
# discuss -> discuss
# more -> more
# examples -> example
# in -> in
# the -> the
# class -> class
# madam -> madam
# explained -> explainer
# the -> the
# oop -> oopak
# concepts -> concept
# clearly -> clearly
# with -> with
# exampleslectures -> exampleless
# were -> were
# interestingwe -> interesting
# want -> want
# more -> more
# scenario -> scenario
# examples -> example
# and -> and
# answers -> answer
# with -> with
# explanations -> explanation
# in -> in
# future -> future
# satisfy -> satisfy
# about -> about
# first -> first
# lectures -> lecturess
# That -> Thad
# way -> way
# of -> of
# teaching -> teaching
# is -> is
# really -> really
# good -> good
# for -> for
# coming -> coming
# lectures -> lecturess
# too -> too
# lectuers -> lecturer
# are -> are
# very -> very
# good -> good
# take -> take
# good -> good
# effort -> effort
# to -> to
# make -> make
# undersatand -> understand
# every -> every
# student -> student
# in -> in
# the -> the
# room -> room
# very -> very
# helpfull -> helpfully
# was -> was
# able -> able
# to -> to
# obtain -> obtain
# clear -> clear
# picture -> picture
# about -> about
# OOP -> O
# and -> and
# its -> its
# concepts -> concept
# lecture -> lecture
# slides -> slide
# explanations -> explanation
# were -> were
# very -> very
# clear -> clear
# br -> bra
# its -> its
# very -> very
# good -> good
# to -> to
# letting -> lettering
# ask -> ask
# questions -> question
# and -> and
# explain -> explain
# again -> again
# with -> with
# suitable -> suitable
# examples -> example
# br -> bra
# sometimes -> sometimes
# some -> some
# codes -> code
# on -> on
# white -> white
# board -> board
# were -> were
# unclear -> unclear
# at -> at
# the -> the
# back -> back
# br -> bra
# overall -> overall
# very -> very
# good -> good
# br -> bra
# The -> The
# lectures -> lecturess
# were -> were
# good -> good
# and -> and
# clear -> clear
# And -> Ande
# they -> they
# werent -> werent
# too -> too
# fast -> fast
# Writing -> Waring
# code -> code
# was -> was
# somewhat -> somewhat
# confusing -> confusingly
# because -> because
# didnt -> didnt
# know -> know
# java -> javali
# before -> before
# Actually -> Acalypha
# teaching -> teaching
# is -> is
# very -> very
# good -> good
# and -> and
# can -> can
# understand -> understand
# easily -> easily
# the -> the
# concepts -> concept
# by -> by
# examples -> example
# which -> which
# are -> are
# given -> given
# in -> in
# the -> the
# classit -> classic
# will -> will
# be -> be
# more -> more
# helpful -> helpful
# if -> if
# provide -> provide
# solved -> solve
# questions -> question
# as -> as
# well -> well
# thankyou -> thank
#  Hesione last seven lecturess are good  Les are understandable  Latrodectus slide are very useful to study also  The given opportunity to ask question from the lecturer is appreciative   God   bra   please do recap at class starting its better for us   bra   sometimes teaching speed is very high   bra    bra   Thalian    bra    The lecturess are good  but a bit speed  A in class working activity is a must one please take another hour in thurse madame    bra   Wea can hear your voice clearly and can understand the thing you teach  Predentata slide also good source to refer  l you can do more example question within the classroom and it will help us to understand the principle well   bra    Les was well structured and well organized  Ita was easy to understand  Latrodectus slide and lab were also well organized  Les were good  understandable  The lecture slide were well organized and the example done in the class helper a lot to learn this new language and also the principle of O  Morcote to well  Wogulian have been better if we discusser more about the solution of codding exercise  I think i learned a lot from the code you write in the board  Wend i compare my code with yours i can learn about my mistake and good codding practice that i should follow  Theresa fore i think it would be great if we can discuss more example in the class  madam explainer the oopak concept clearly with exampleless were interesting want more scenario example and answer with explanation in future  I satisfy about first 7 lecturess  Thad way of teaching is really good for coming lecturess too  lecturer are very good  take good effort to make understand every student in the room  very helpfully  I was able to obtain a clear picture about O and its concept   lecture slide  explanation were very clear   bra   its very good to lettering ask question and explain again with suitable example   bra   sometimes  some code on white board were unclear at the back   bra   overall very good     bra    The lecturess were good and clear  Ande they werent too fast  Waring code was somewhat confusingly because I didnt know javali before  Acalypha teaching is very good and can understand easily the concept by example which are given in the classic will be more helpful if provide solve question as well   thank
# ' Hesione last seven lecturess are good  Les are understandable  Latrodectus slide are very useful to study also  The given opportunity to ask question from the lecturer is appreciative   God   bra   please do recap at class starting its better for us   bra   sometimes teaching speed is very high   bra    bra   Thalian    bra    The lecturess are good  but a bit speed  A in class working activity is a must one please take another hour in thurse madame    bra   Wea can hear your voice clearly and can understand the thing you teach  Predentata slide also good source to refer  l you can do more example question within the classroom and it will help us to understand the principle well   bra    Les was well structured and well organized  Ita was easy to understand  Latrodectus slide and lab were also well organized  Les were good  understandable  The lecture slide were well organized and the example done in the class helper a lot to learn this new language and also the principle of O  Morcote to well  Wogulian have been better if we discusser more about the solution of codding exercise  I think i learned a lot from the code you write in the board  Wend i compare my code with yours i can learn about my mistake and good codding practice that i should follow  Theresa fore i think it would be great if we can discuss more example in the class  madam explainer the oopak concept clearly with exampleless were interesting want more scenario example and answer with explanation in future  I satisfy about first 7 lecturess  Thad way of teaching is really good for coming lecturess too  lecturer are very good  take good effort to make understand every student in the room  very helpfully  I was able to obtain a clear picture about O and its concept   lecture slide  explanation were very clear   bra   its very good to lettering ask question and explain again with suitable example   bra   sometimes  some code on white board were unclear at the back   bra   overall very good     bra    The lecturess were good and clear  Ande they werent too fast  Waring code was somewhat confusingly because I didnt know javali before  Acalypha teaching is very good and can understand easily the concept by example which are given in the classic will be more helpful if provide solve question as well   thank'

# %% [markdown]
# Question 03: Lemmatization

# %%
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
from nltk import word_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
def lemmatizeText(text):
  for word in text:
    print(word + ": ", lemmatizer.lemmatize(word, pos="a"))


print("================ Lemmatized student feedback =================\n")
lemmatized_student_feedback = lemmatizeText(tokenized_student_feedback);
# Out:
# ================ Lemmatized student feedback =================
#
# Honestly:  Honestly
# last:  last
# seven:  seven
# lectures:  lectures
# are:  are
# good:  good
# .:  .
# Lectures:  Lectures
# are:  are
# understandable:  understandable
# .:  .
# Lecture:  Lecture
# slides:  slides
# are:  are
# very:  very
# useful:  useful
# to:  to
# self-study:  self-study
# also:  also
# .:  .
# The:  The
# given:  given
# opportunity:  opportunity
# to:  to
# ask:  ask
# questions:  questions
# from:  from
# the:  the
# lecturer:  lecturer
# is:  is
# appreciative:  appreciative
# .:  .
# ":  "
# Good:  Good
# :):  :)
# <:  <
# br:  br
# /:  /
# >:  >
# please:  please
# do:  do
# recap:  recap
# at:  at
# class:  class
# starting:  starting
# it's:  it's
# better:  good
# for:  for
# us:  us
# .:  .
# <:  <
# br:  br
# /:  /
# >:  >
# sometimes:  sometimes
# teaching:  teaching
# speed:  speed
# is:  is
# very:  very
# high:  high
# .:  .
# <:  <
# br:  br
# /:  /
# >:  >
# <:  <
# br:  br
# /:  /
# >:  >
# Thanks:  Thanks
# !:  !
# :):  :)
# <:  <
# br:  br
# /:  /
# >:  >
# ":  "
# The:  The
# lectures:  lectures
# are:  are
# good:  good
# ..:  ..
# but:  but
# a:  a
# bit:  bit
# speed:  speed
# .:  .
# A:  A
# in:  in
# class:  class
# working:  working
# activity:  activity
# is:  is
# a:  a
# must:  must
# one.So:  one.So
# please:  please
# take:  take
# another:  another
# hour:  hour
# in:  in
# thursdays:  thursdays
# madame:  madame
# .:  .
# ":  "
# <:  <
# br:  br
# /:  /
# >:  >
# We:  We
# can:  can
# hear:  hear
# your:  your
# voice:  voice
# clearly:  clearly
# and:  and
# can:  can
# understand:  understand
# the:  the
# things:  things
# you:  you
# teach:  teach
# .:  .
# Presentation:  Presentation
# slides:  slides
# also:  also
# good:  good
# source:  source
# to:  to
# refer:  refer
# .:  .
# lf:  lf
# you:  you
# can:  can
# do:  do
# more:  more
# example:  example
# questions:  questions
# within:  within
# the:  the
# classroom:  classroom
# and:  and
# it:  it
# will:  will
# help:  help
# us:  us
# to:  to
# understand:  understand
# the:  the
# principles:  principles
# well:  well
# .:  .
# <:  <
# br:  br
# /:  /
# >:  >
# ":  "
# Lectures:  Lectures
# was:  was
# well:  well
# structured:  structured
# and:  and
# well:  well
# organized:  organized
# .:  .
# It:  It
# was:  was
# easy:  easy
# to:  to
# understand:  understand
# .:  .
# Lecture:  Lecture
# slides:  slides
# and:  and
# labs:  labs
# were:  were
# also:  also
# well:  well
# organized:  organized
# .:  .
# Lectures:  Lectures
# were:  were
# good:  good
# .:  .
# understandable:  understandable
# .:  .
# The:  The
# lecture:  lecture
# slides:  slides
# were:  were
# well:  well
# organized:  organized
# and:  and
# the:  the
# examples:  examples
# done:  done
# in:  in
# the:  the
# class:  class
# helped:  helped
# a:  a
# lot:  lot
# to:  to
# learn:  learn
# this:  this
# new:  new
# language:  language
# and:  and
# also:  also
# the:  the
# principles:  principles
# of:  of
# OOP:  OOP
# .:  .
# Motivated:  Motivated
# to:  to
# well:  well
# .:  .
# Would:  Would
# have:  have
# been:  been
# better:  good
# if:  if
# we:  we
# discussed:  discussed
# more:  more
# about:  about
# the:  the
# solutions:  solutions
# of:  of
# coding:  coding
# exercisers:  exercisers
# .:  .
# I:  I
# think:  think
# i:  i
# learned:  learned
# a:  a
# lot:  lot
# from:  from
# the:  the
# codes:  codes
# you:  you
# write:  write
# in:  in
# the:  the
# board:  board
# .:  .
# When:  When
# i:  i
# compare:  compare
# my:  my
# codes:  codes
# with:  with
# yours:  yours
# i:  i
# can:  can
# learn:  learn
# about:  about
# my:  my
# mistakes:  mistakes
# and:  and
# good:  good
# coding:  coding
# practices:  practices
# that:  that
# i:  i
# should:  should
# follow:  follow
# .:  .
# There:  There
# fore:  fore
# i:  i
# think:  think
# it:  it
# would:  would
# be:  be
# great:  great
# if:  if
# we:  we
# can:  can
# discuss:  discuss
# more:  more
# examples:  examples
# in:  in
# the:  the
# class:  class
# .:  .
# madam:  madam
# explained:  explained
# the:  the
# oop:  oop
# concepts:  concepts
# clearly:  clearly
# with:  with
# examples.lectures:  examples.lectures
# were:  were
# interesting.we:  interesting.we
# want:  want
# more:  more
# scenario:  scenario
# examples:  examples
# and:  and
# answers:  answers
# with:  with
# explanations:  explanations
# in:  in
# future:  future
# .:  .
# I:  I
# satisfy:  satisfy
# about:  about
# first:  first
# 7:  7
# lectures:  lectures
# .:  .
# That:  That
# way:  way
# of:  of
# teaching:  teaching
# is:  is
# really:  really
# good:  good
# for:  for
# coming:  coming
# lectures:  lectures
# too:  too
# .:  .
# lectuers:  lectuers
# are:  are
# very:  very
# good:  good
# .:  .
# take:  take
# good:  good
# effort:  effort
# to:  to
# make:  make
# undersatand:  undersatand
# every:  every
# student:  student
# in:  in
# the:  the
# room:  room
# .:  .
# very:  very
# helpfull:  helpfull
# .:  .
# I:  I
# was:  was
# able:  able
# to:  to
# obtain:  obtain
# a:  a
# clear:  clear
# picture:  picture
# about:  about
# OOP:  OOP
# and:  and
# its:  its
# concepts:  concepts
# .:  .
# ":  "
# lecture:  lecture
# slides:  slides
# ,:  ,
# explanations:  explanations
# were:  were
# very:  very
# clear:  clear
# .:  .
# <:  <
# br:  br
# /:  /
# >:  >
# it's:  it's
# very:  very
# good:  good
# to:  to
# letting:  letting
# ask:  ask
# questions:  questions
# and:  and
# explain:  explain
# again:  again
# with:  with
# suitable:  suitable
# examples:  examples
# .:  .
# <:  <
# br:  br
# /:  /
# >:  >
# sometimes:  sometimes
# ,:  ,
# some:  some
# codes:  codes
# on:  on
# white:  white
# board:  board
# were:  were
# unclear:  unclear
# at:  at
# the:  the
# back:  back
# .:  .
# <:  <
# br:  br
# /:  /
# >:  >
# overall:  overall
# very:  very
# good:  good
# !:  !
# !:  !
# !:  !
# <:  <
# br:  br
# /:  /
# >:  >
# ":  "
# The:  The
# lectures:  lectures
# were:  were
# good:  good
# and:  and
# clear:  clear
# .:  .
# And:  And
# they:  they
# weren't:  weren't
# too:  too
# fast:  fast
# .:  .
# Writing:  Writing
# code:  code
# was:  was
# somewhat:  somewhat
# confusing:  confusing
# because:  because
# I:  I
# didn't:  didn't
# know:  know
# java:  java
# before:  before
# .:  .
# Actually:  Actually
# teaching:  teaching
# is:  is
# very:  very
# good:  good
# and:  and
# can:  can
# understand:  understand
# easily:  easily
# the:  the
# concepts:  concepts
# by:  by
# examples:  examples
# which:  which
# are:  are
# given:  given
# in:  in
# the:  the
# class.it:  class.it
# will:  will
# be:  be
# more:  more
# helpful:  helpful
# if:  if
# provide:  provide
# solved:  solved
# questions:  questions
# as:  as
# well:  well
# !:  !
# .:  .
# thankyou:  thankyou

# %%
print("================ Lemmatized research paper =================\n")
lemmatized_research_paper = lemmatizeText(tokenized_research_paper);
# Out:
# ================ Lemmatized research paper =================
#
# Neural:  Neural
# network:  network
# models:  models
# have:  have
# shown:  shown
# their:  their
# promising:  promising
# opportunities:  opportunities
# for:  for
# multi-task:  multi-task
# learning:  learning
# ,:  ,
# which:  which
# focus:  focus
# on:  on
# learning:  learning
# the:  the
# shared:  shared
# layers:  layers
# to:  to
# extract:  extract
# the:  the
# common:  common
# and:  and
# task-invariant:  task-invariant
# features:  features
# .:  .
# However:  However
# ,:  ,
# in:  in
# most:  most
# existing:  existing
# approaches:  approaches
# ,:  ,
# the:  the
# extracted:  extracted
# shared:  shared
# features:  features
# are:  are
# prone:  prone
# to:  to
# be:  be
# contaminated:  contaminated
# by:  by
# task-specific:  task-specific
# features:  features
# or:  or
# the:  the
# noise:  noise
# brought:  brought
# by:  by
# other:  other
# tasks:  tasks
# .:  .
# In:  In
# this:  this
# paper:  paper
# ,:  ,
# we:  we
# propose:  propose
# an:  an
# adversarial:  adversarial
# multi-task:  multi-task
# learning:  learning
# framework:  framework
# ,:  ,
# alleviating:  alleviating
# the:  the
# shared:  shared
# and:  and
# private:  private
# latent:  latent
# feature:  feature
# spaces:  spaces
# from:  from
# interfering:  interfering
# with:  with
# each:  each
# other:  other
# .:  .
# We:  We
# conduct:  conduct
# extensive:  extensive
# experiments:  experiments
# on:  on
# 16:  16
# different:  different
# text:  text
# classification:  classification
# tasks:  tasks
# ,:  ,
# which:  which
# demonstrates:  demonstrates
# the:  the
# benefits:  benefits
# of:  of
# our:  our
# approach:  approach
# .:  .
# Besides:  Besides
# ,:  ,
# we:  we
# show:  show
# that:  that
# the:  the
# shared:  shared
# knowledge:  knowledge
# learned:  learned
# by:  by
# our:  our
# proposed:  proposed
# model:  model
# can:  can
# be:  be
# regarded:  regarded
# as:  as
# off-the-shelf:  off-the-shelf
# knowledge:  knowledge
# and:  and
# easily:  easily
# transferred:  transferred
# to:  to
# new:  new
# tasks:  tasks
# .:  .
# Multi-task:  Multi-task
# learning:  learning
# is:  is
# an:  an
# effective:  effective
# approach:  approach
# to:  to
# improve:  improve
# the:  the
# performance:  performance
# of:  of
# a:  a
# single:  single
# task:  task
# with:  with
# the:  the
# help:  help
# of:  of
# other:  other
# related:  related
# tasks:  tasks
# .:  .
# Recently:  Recently
# ,:  ,
# neural-based:  neural-based
# models:  models
# for:  for
# multi-task:  multi-task
# learning:  learning
# have:  have
# become:  become
# very:  very
# popular:  popular
# ,:  ,
# ranging:  ranging
# from:  from
# computer:  computer
# vision:  vision
# (:  (
# Misra:  Misra
# et:  et
# al:  al
# .:  .
# ,:  ,
# 2016:  2016
# ;:  ;
# Zhang:  Zhang
# et:  et
# al:  al
# .:  .
# ,:  ,
# 2014:  2014
# ):  )
# to:  to
# natural:  natural
# language:  language
# processing:  processing
# (:  (
# Collobert:  Collobert
# andWeston:  andWeston
# ,:  ,
# 2008:  2008
# ;:  ;
# Luong:  Luong
# et:  et
# al:  al
# .:  .
# ,:  ,
# 2015:  2015
# ):  )
# ,:  ,
# since:  since
# they:  they
# provide:  provide
# a:  a
# convenient:  convenient
# way:  way
# of:  of
# combining:  combining
# information:  information
# from:  from
# multiple:  multiple
# tasks:  tasks
# .:  .
# However:  However
# ,:  ,
# most:  most
# existing:  existing
# work:  work
# on:  on
# multi-task:  multi-task
# learning:  learning
# (:  (
# Liu:  Liu
# et:  et
# al:  al
# .:  .
# ,:  ,
# 2016c:  2016c
# ,:  ,
# b:  b
# ):  )
# attempts:  attempts
# to:  to
# divide:  divide
# the:  the
# features:  features
# of:  of
# different:  different
# tasks:  tasks
# into:  into
# private:  private
# and:  and
# shared:  shared
# spaces:  spaces
# ,:  ,
# merely:  merely
# based:  based
# on:  on
# whether:  whether
# parameters:  parameters
# of:  of
# some:  some
# components:  components
# should:  should
# be:  be
# shared:  shared
# .:  .
# As:  As
# shown:  shown
# in:  in
# Figure:  Figure
# 1:  1
# -:  -
# (:  (
# a:  a
# ):  )
# ,:  ,
# the:  the
# general:  general
# shared-private:  shared-private
# model:  model
# introduces:  introduces
# two:  two
# feature:  feature
# spaces:  spaces
# for:  for
# any:  any
# task:  task
# ::  :
# one:  one
# is:  is
# used:  used
# to:  to
# store:  store
# task-dependent:  task-dependent
# features:  features
# ,:  ,
# the:  the
# other:  other
# is:  is
# used:  used
# to:  to
# capture:  capture
# shared:  shared
# features:  features
# .:  .
# The:  The
# major:  major
# limitation:  limitation
# of:  of
# this:  this
# framework:  framework
# is:  is
# that:  that
# the:  the
# shared:  shared
# feature:  feature
# space:  space
# could:  could
# contain:  contain
# some:  some
# unnecessary:  unnecessary
# task-specific:  task-specific
# features:  features
# ,:  ,
# while:  while
# some:  some
# sharable:  sharable
# features:  features
# could:  could
# also:  also
# be:  be
# mixed:  mixed
# in:  in
# private:  private
# space:  space
# ,:  ,
# suffering:  suffering
# from:  from
# feature:  feature
# redundancy:  redundancy
# .:  .
# Taking:  Taking
# the:  the
# following:  following
# two:  two
# sentences:  sentences
# as:  as
# examples:  examples
# ,:  ,
# which:  which
# are:  are
# extracted:  extracted
# from:  from
# two:  two
# different:  different
# sentiment:  sentiment
# classification:  classification
# tasks:  tasks
# ::  :
# Movie:  Movie
# reviews:  reviews
# and:  and
# Baby:  Baby
# products:  products
# reviews:  reviews
# .:  .
# The:  The
# infantile:  infantile
# cart:  cart
# is:  is
# simple:  simple
# and:  and
# easy:  easy
# to:  to
# use:  use
# .:  .
# This:  This
# kind:  kind
# of:  of
# humour:  humour
# is:  is
# infantile:  infantile
# and:  and
# boring:  boring
# .:  .
# The:  The
# word:  word
# �:  �
# infantile:  infantile
# �:  �
# indicates:  indicates
# negative:  negative
# sentiment:  sentiment
# in:  in
# Movie:  Movie
# task:  task
# while:  while
# it:  it
# is:  is
# neutral:  neutral
# in:  in
# Baby:  Baby
# task:  task
# .:  .
# However:  However
# ,:  ,
# the:  the
# general:  general
# shared-private:  shared-private
# model:  model
# could:  could
# place:  place
# the:  the
# task-specific:  task-specific
# word:  word
# �:  �
# infantile:  infantile
# �:  �
# in:  in
# a:  a
# shared:  shared
# space:  space
# ,:  ,
# leaving:  leaving
# potential:  potential
# hazards:  hazards
# for:  for
# other:  other
# tasks:  tasks
# .:  .
# Additionally:  Additionally
# ,:  ,
# the:  the
# capacity:  capacity
# of:  of
# shared:  shared
# space:  space
# could:  could
# also:  also
# be:  be
# wasted:  wasted
# by:  by
# some:  some
# unnecessary:  unnecessary
# features:  features
# .:  .
# To:  To
# address:  address
# this:  this
# problem:  problem
# ,:  ,
# in:  in
# this:  this
# paper:  paper
# we:  we
# propose:  propose
# an:  an
# adversarial:  adversarial
# multi-task:  multi-task
# framework:  framework
# ,:  ,
# in:  in
# which:  which
# the:  the
# shared:  shared
# and:  and
# private:  private
# feature:  feature
# spaces:  spaces
# are:  are
# in:  in
# herently:  herently
# disjoint:  disjoint
# by:  by
# introducing:  introducing
# orthogonality:  orthogonality
# constraints.Specifically:  constraints.Specifically
# ,:  ,
# we:  we
# design:  design
# a:  a
# generic:  generic
# shared:  shared
# private:  private
# learning:  learning
# framework:  framework
# to:  to
# model:  model
# the:  the
# text:  text
# sequence:  sequence
# .:  .

# %%
print("================ Lemmatized twitter =================\n")
lemmatized_twitter = lemmatizeText(tokenized_twitter);
# Out:
# ================ Lemmatized twitter =================
#
# Reminds:  Reminds
# me:  me
# of:  of
# Liberal:  Liberal
# Immigration:  Immigration
# Fraudster:  Fraudster
# Monsef:  Monsef
# avoiding:  avoiding
# deportation:  deportation
# from:  from
# Canada:  Canada
# .:  .
# #cdnpoli:  #cdnpoli
# #LPC:  #LPC
# #CPCLDR:  #CPCLDR
# �:  �
# �:  �
# _:  _
# https://t.co/ZOZOSe1CqQ:  https://t.co/ZOZOSe1CqQ
# #immigration:  #immigration
# #integration:  #integration
# #canada:  #canada
# https://t.co/M5cKGyvV8F:  https://t.co/M5cKGyvV8F
# We:  We
# want:  want
# controlled:  controlled
# immigration:  immigration
# that:  that
# contributes:  contributes
# positively:  positively
# to:  to
# the:  the
# UK:  UK
# economy:  economy
# .:  .
# Same:  Same
# as:  as
# Australia:  Australia
# &:  &
# Canada:  Canada
# .:  .
# https://t.co/99mYliuOes:  https://t.co/99mYliuOes
# Is:  Is
# the:  the
# new:  new
# Manitoba:  Manitoba
# immigration:  immigration
# fee:  fee
# a:  a
# head:  head
# tax:  tax
# ?:  ?
# https://t.co/LsG7C3vLe9:  https://t.co/LsG7C3vLe9
# Canada:  Canada
# immigration:  immigration
# profit:  profit
# influence:  influence
# modernistic:  modernistic
# delhi:  delhi
# yet:  yet
# abhinav:  abhinav
# ::  :
# XKofy:  XKofy
# https://t.co/becgusY2i6:  https://t.co/becgusY2i6
# Canada:  Canada
# Immigration:  Immigration
# Minister:  Minister
# to:  to
# �:  �
# �:  �
# �:  �
# Substantially:  Substantially
# Increase:  Increase
# Immigration:  Immigration
# Numbers:  Numbers
# https://t.co/nEFw30MRaa:  https://t.co/nEFw30MRaa
# https://t.co/cyI867PZRV:  https://t.co/cyI867PZRV
# M:  M
# �:  �
# �:  �
# me:  me
# les:  les
# #USA:  #USA
# =p:  =p
# ays:  ays
# d'immigration:  d'immigration
# par:  par
# excellence:  excellence
# CONTR:  CONTR
# �:  �
# �:  �
# LE:  LE
# RIGOUREUSEMENT:  RIGOUREUSEMENT
# l'immigration:  l'immigration
# et:  et
# acc:  acc
# �:  �
# �:  �
# s:  s
# �:  �
# �:  �
# la:  la
# #GreenCARD:  #GreenCARD
# !:  !
# �:  �
# �:  �
# _:  _
# https://t.co/IHpVhW2BaG:  https://t.co/IHpVhW2BaG
# what:  what
# changes:  changes
# should:  should
# be:  be
# made:  made
# to:  to
# Canada's:  Canada's
# immigration:  immigration
# laws:  laws
# due:  due
# to:  to
# the:  the
# influx:  influx
# of:  of
# immigration:  immigration
# and:  and
# violence:  violence
# ?:  ?
# L:  L
# �:  �
# �:  �
# immigration:  immigration
# irr:  irr
# �:  �
# �:  �
# guli:  guli
# �:  �
# �:  �
# re:  re
# au:  au
# Canada:  Canada
# d:  d
# �:  �
# �:  �
# cortiqu:  cortiqu
# �:  �
# �:  �
# e:  e
# en:  en
# 5:  5
# questions:  questions
# https://t.co/f4utO5A7ZF:  https://t.co/f4utO5A7ZF
# L'immigration:  L'immigration
# irr:  irr
# �:  �
# �:  �
# guli:  guli
# �:  �
# �:  �
# re:  re
# au:  au
# Canada:  Canada
# d:  d
# �:  �
# �:  �
# cortiqu:  cortiqu
# �:  �
# �:  �
# e:  e
# en:  en
# 5:  5
# questions:  questions
# -:  -
# https://t.co/UiBsEZOqas:  https://t.co/UiBsEZOqas
# https://t.co/j77dEvjoiX:  https://t.co/j77dEvjoiX
# https://t.co/XXDeIG7Dbu:  https://t.co/XXDeIG7Dbu
# Will:  Will
# Media:  Media
# ask:  ask
# the:  the
# Liberals:  Liberals
# if:  if
# they:  they
# actually:  actually
# have:  have
# a:  a
# solid:  solid
# plan:  plan
# for:  for
# Canada:  Canada
# _:  _
# �:  �
# �:  �
# _:  _
# �:  �
# _:  _
# ?:  ?
# ?:  ?
# From:  From
# my:  my
# view:  view
# -:  -
# -:  -
# immigration:  immigration
# out:  out
# of:  of
# C:  C
# �:  �
# �:  �
# _:  _
# https://t.co/YAgwmZ8ECp:  https://t.co/YAgwmZ8ECp
# Dan:  Dan
# Murray:  Murray
# of:  of
# �:  �
# �:  �
# Immigration:  Immigration
# Watch:  Watch
# Canada:  Canada
# is:  is
# xenophobic:  xenophobic
# racist:  racist
# fear-mongering:  fear-mongering
# liar:  liar
# #racism:  #racism
# #canada:  #canada
# #cdnpoli:  #cdnpoli
# #hatecrime:  #hatecrime
# �:  �
# �:  �
# _:  _
# https://t.co/kwZ3csvYxM:  https://t.co/kwZ3csvYxM
# Le:  Le
# Canada:  Canada
# lance:  lance
# une:  une
# vaste:  vaste
# campagne:  campagne
# d'immigration:  d'immigration
# pour:  pour
# faire:  faire
# face:  face
# �:  �
# �:  �
# son:  son
# besoin:  besoin
# de:  de
# main:  main
# d:  d
# ':  '
# �:  �
# �:  �
# uvre:  uvre
# https://t.co/kXdfMGTZzN:  https://t.co/kXdfMGTZzN
# L:  L
# �:  �
# �:  �
# #immigration:  #immigration
# irr:  irr
# �:  �
# �:  �
# guli:  guli
# �:  �
# �:  �
# re:  re
# au:  au
# #Canada:  #Canada
# d:  d
# �:  �
# �:  �
# cortiqu:  cortiqu
# �:  �
# �:  �
# e:  e
# en:  en
# 5:  5
# �:  �
# �:  �
# questions:  questions
# https://t.co/s3hu1OKKIG:  https://t.co/s3hu1OKKIG
# I've:  I've
# read:  read
# the:  the
# Immigration:  Immigration
# laws:  laws
# of:  of
# Canada:  Canada
# much:  much
# stricter:  strict
# than:  than
# the:  the
# US:  US
# Canada:  Canada
# Immigration:  Immigration
# Website:  Website
# Traffic:  Traffic
# Surges:  Surges
# And:  And
# Crashes:  Crashes
# In:  In
# Wake:  Wake
# Of:  Of
# Trump:  Trump
# #fasttraffic:  #fasttraffic
# ,:  ,
# #sitetraffic:  #sitetraffic
# ,:  ,
# #website:  #website
# ,:  ,
# #traffic:  #traffic
# https://t.co/zRlJ26jnkC:  https://t.co/zRlJ26jnkC
# Mr:  Mr
# Know-all:  Know-all
# of:  of
# Canada:  Canada
# Immigration:  Immigration
# https://t.co/wTQK4QDiKI:  https://t.co/wTQK4QDiKI
# Move:  Move
# to:  to
# Canada:  Canada
# Oh:  Oh
# ,:  ,
# immigration:  immigration
# rules:  rules
# ,:  ,
# you:  you
# can't:  can't
# ...:  ...
# https://t.co/5LIEVHO7A4:  https://t.co/5LIEVHO7A4
# #OnThisDay:  #OnThisDay
# Annette:  Annette
# Toft:  Toft
# becomes:  becomes
# Canada's:  Canada's
# 2:  2
# millionth:  millionth
# immigrant:  immigrant
# since:  since
# 1945:  1945
# .:  .
# Do:  Do
# you:  you
# know:  know
# your:  your
# family's:  family's
# immigration:  immigration
# st:  st
# �:  �
# �:  �
# _:  _
# https://t.co/UvRuw8eR1b:  https://t.co/UvRuw8eR1b
# .:  .
# profiles:  profiles
# Canada's:  Canada's
# open:  open
# immigration:  immigration
# policies:  policies
# &:  &
# how:  how
# they:  they
# contribute:  contribute
# to:  to
# our:  our
# economic:  economic
# success:  success
# ::  :
# �:  �
# �:  �
# _:  _
# https://t.co/4K84EE8Y63:  https://t.co/4K84EE8Y63
# Hundreds:  Hundreds
# may:  may
# lose:  lose
# Canadian:  Canadian
# citizenship:  citizenship
# ,:  ,
# resident:  resident
# status:  status
# because:  because
# of:  of
# one:  one
# corrupt:  corrupt
# immigration:  immigration
# consultant:  consultant
# https://t.co/x2IfO0EXI2:  https://t.co/x2IfO0EXI2
# Immigration:  Immigration
# for:  for
# canada:  canada
# without:  without
# india:  india
# ::  :
# an:  an
# compassionate:  compassionate
# handle:  handle
# ::  :
# deyFy:  deyFy
# ":  "
# #Jamaican:  #Jamaican
# #immigrants:  #immigrants
# #Canada:  #Canada
# https://t.co/vcmfYGadR5:  https://t.co/vcmfYGadR5
# #statistics:  #statistics
# #immigration:  #immigration
# ":  "
# Mexican:  Mexican
# visa:  visa
# lift:  lift
# expected:  expected
# to:  to
# cost:  cost
# Canada:  Canada
# $:  $
# 262M:  262M
# over:  over
# a:  a
# decade:  decade
# https://t.co/9i72fRhtij:  https://t.co/9i72fRhtij
# Are:  Are
# people:  people
# still:  still
# moving:  moving
# to:  to
# #Canada:  #Canada
# ?:  ?
# ?:  ?
# ?:  ?
# Oh:  Oh
# that's:  that's
# right:  right
# ,:  ,
# they:  they
# have:  have
# real:  real
# immigration:  immigration
# laws:  laws
# and:  and
# it's:  it's
# �:  �
# �:  �
# _:  _
# https://t.co/0C5OBfmxLG:  https://t.co/0C5OBfmxLG
# Here:  Here
# are:  are
# more:  more
# details:  details
# on:  on
# the:  the
# Richmond:  Richmond
# ,:  ,
# B:  B
# .:  .
# C:  C
# .:  .
# Immigration:  Immigration
# Consultant:  Consultant
# Sunny:  Sunny
# Wang:  Wang
# who:  who
# was:  was
# sentenced:  sentenced
# to:  to
# 7:  7
# years:  years
# in:  in
# ...:  ...
# https://t.co/YXH5W53srO:  https://t.co/YXH5W53srO
# I:  I
# added:  added
# a:  a
# video:  video
# to:  to
# a:  a
# playlist:  playlist
# https://t.co/CnEyWN40x3:  https://t.co/CnEyWN40x3
# Funny:  Funny
# Talking:  Talking
# of:  of
# Haryanavi:  Haryanavi
# Jat:  Jat
# with:  with
# Canada:  Canada
# Immigration:  Immigration
# Girl:  Girl
# Agent:  Agent
# Mexicans:  Mexicans
# Can:  Can
# Now:  Now
# Travel:  Travel
# Visa-Free:  Visa-Free
# To:  To
# Canada:  Canada
# https://t.co/Ec3XHORO2s:  https://t.co/Ec3XHORO2s
# https://t.co/RQRr5nebcG:  https://t.co/RQRr5nebcG
# L:  L
# �:  �
# �:  �
# immigration:  immigration
# irr:  irr
# �:  �
# �:  �
# guli:  guli
# �:  �
# �:  �
# re:  re
# au:  au
# Canada:  Canada
# d:  d
# �:  �
# �:  �
# cortiqu:  cortiqu
# �:  �
# �:  �
# e:  e
# en:  en
# 5:  5
# �:  �
# �:  �
# questions:  questions
# https://t.co/DkpuKyWmaK:  https://t.co/DkpuKyWmaK
# Hes:  Hes
# the:  the
# POS:  POS
# that:  that
# ramped:  ramped
# up:  up
# immigration:  immigration
# for:  for
# Canada:  Canada
# ,:  ,
# among:  among
# other:  other
# globalist:  globalist
# policies:  policies
# .:  .
# Canada:  Canada
# lifted:  lifted
# visa:  visa
# requirements:  requirements
# to:  to
# Mexico:  Mexico
# as:  as
# of:  of
# Dec:  Dec
# 1:  1
# ,:  ,
# 2016:  2016
# .:  .
# Thoughts:  Thoughts
# ?:  ?
# #visa:  #visa
# #immigration:  #immigration
# people:  people
# Keep:  Keep
# praising:  praising
# Canada:  Canada
# and:  and
# Canada:  Canada
# has:  has
# way:  way
# stricter:  strict
# immigration:  immigration
# laws:  laws
# then:  then
# us:  us
# they:  they
# willl:  willl
# boot:  boot
# your:  your
# liberal:  liberal
# American:  American
# ass:  ass

# %% [markdown]
# Stemmer: Porter Stemmer

# %%
# import these modules
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
  
ps = PorterStemmer()

# %%
print("===================Research Paper===================")
for word in tokenized_research_paper:
  print(word, " : ", ps.stem(word))
# Out:
# ===================Research Paper===================
# Neural  :  neural
# network  :  network
# models  :  model
# have  :  have
# shown  :  shown
# their  :  their
# promising  :  promis
# opportunities  :  opportun
# for  :  for
# multi-task  :  multi-task
# learning  :  learn
# ,  :  ,
# which  :  which
# focus  :  focu
# on  :  on
# learning  :  learn
# the  :  the
# shared  :  share
# layers  :  layer
# to  :  to
# extract  :  extract
# the  :  the
# common  :  common
# and  :  and
# task-invariant  :  task-invari
# features  :  featur
# .  :  .
# However  :  howev
# ,  :  ,
# in  :  in
# most  :  most
# existing  :  exist
# approaches  :  approach
# ,  :  ,
# the  :  the
# extracted  :  extract
# shared  :  share
# features  :  featur
# are  :  are
# prone  :  prone
# to  :  to
# be  :  be
# contaminated  :  contamin
# by  :  by
# task-specific  :  task-specif
# features  :  featur
# or  :  or
# the  :  the
# noise  :  nois
# brought  :  brought
# by  :  by
# other  :  other
# tasks  :  task
# .  :  .
# In  :  In
# this  :  thi
# paper  :  paper
# ,  :  ,
# we  :  we
# propose  :  propos
# an  :  an
# adversarial  :  adversari
# multi-task  :  multi-task
# learning  :  learn
# framework  :  framework
# ,  :  ,
# alleviating  :  allevi
# the  :  the
# shared  :  share
# and  :  and
# private  :  privat
# latent  :  latent
# feature  :  featur
# spaces  :  space
# from  :  from
# interfering  :  interf
# with  :  with
# each  :  each
# other  :  other
# .  :  .
# We  :  We
# conduct  :  conduct
# extensive  :  extens
# experiments  :  experi
# on  :  on
# 16  :  16
# different  :  differ
# text  :  text
# classification  :  classif
# tasks  :  task
# ,  :  ,
# which  :  which
# demonstrates  :  demonstr
# the  :  the
# benefits  :  benefit
# of  :  of
# our  :  our
# approach  :  approach
# .  :  .
# Besides  :  besid
# ,  :  ,
# we  :  we
# show  :  show
# that  :  that
# the  :  the
# shared  :  share
# knowledge  :  knowledg
# learned  :  learn
# by  :  by
# our  :  our
# proposed  :  propos
# model  :  model
# can  :  can
# be  :  be
# regarded  :  regard
# as  :  as
# off-the-shelf  :  off-the-shelf
# knowledge  :  knowledg
# and  :  and
# easily  :  easili
# transferred  :  transfer
# to  :  to
# new  :  new
# tasks  :  task
# .  :  .
# Multi-task  :  multi-task
# learning  :  learn
# is  :  is
# an  :  an
# effective  :  effect
# approach  :  approach
# to  :  to
# improve  :  improv
# the  :  the
# performance  :  perform
# of  :  of
# a  :  a
# single  :  singl
# task  :  task
# with  :  with
# the  :  the
# help  :  help
# of  :  of
# other  :  other
# related  :  relat
# tasks  :  task
# .  :  .
# Recently  :  recent
# ,  :  ,
# neural-based  :  neural-bas
# models  :  model
# for  :  for
# multi-task  :  multi-task
# learning  :  learn
# have  :  have
# become  :  becom
# very  :  veri
# popular  :  popular
# ,  :  ,
# ranging  :  rang
# from  :  from
# computer  :  comput
# vision  :  vision
# (  :  (
# Misra  :  misra
# et  :  et
# al  :  al
# .  :  .
# ,  :  ,
# 2016  :  2016
# ;  :  ;
# Zhang  :  zhang
# et  :  et
# al  :  al
# .  :  .
# ,  :  ,
# 2014  :  2014
# )  :  )
# to  :  to
# natural  :  natur
# language  :  languag
# processing  :  process
# (  :  (
# Collobert  :  collobert
# andWeston  :  andweston
# ,  :  ,
# 2008  :  2008
# ;  :  ;
# Luong  :  luong
# et  :  et
# al  :  al
# .  :  .
# ,  :  ,
# 2015  :  2015
# )  :  )
# ,  :  ,
# since  :  sinc
# they  :  they
# provide  :  provid
# a  :  a
# convenient  :  conveni
# way  :  way
# of  :  of
# combining  :  combin
# information  :  inform
# from  :  from
# multiple  :  multipl
# tasks  :  task
# .  :  .
# However  :  howev
# ,  :  ,
# most  :  most
# existing  :  exist
# work  :  work
# on  :  on
# multi-task  :  multi-task
# learning  :  learn
# (  :  (
# Liu  :  liu
# et  :  et
# al  :  al
# .  :  .
# ,  :  ,
# 2016c  :  2016c
# ,  :  ,
# b  :  b
# )  :  )
# attempts  :  attempt
# to  :  to
# divide  :  divid
# the  :  the
# features  :  featur
# of  :  of
# different  :  differ
# tasks  :  task
# into  :  into
# private  :  privat
# and  :  and
# shared  :  share
# spaces  :  space
# ,  :  ,
# merely  :  mere
# based  :  base
# on  :  on
# whether  :  whether
# parameters  :  paramet
# of  :  of
# some  :  some
# components  :  compon
# should  :  should
# be  :  be
# shared  :  share
# .  :  .
# As  :  As
# shown  :  shown
# in  :  in
# Figure  :  figur
# 1  :  1
# -  :  -
# (  :  (
# a  :  a
# )  :  )
# ,  :  ,
# the  :  the
# general  :  gener
# shared-private  :  shared-priv
# model  :  model
# introduces  :  introduc
# two  :  two
# feature  :  featur
# spaces  :  space
# for  :  for
# any  :  ani
# task  :  task
# :  :  :
# one  :  one
# is  :  is
# used  :  use
# to  :  to
# store  :  store
# task-dependent  :  task-depend
# features  :  featur
# ,  :  ,
# the  :  the
# other  :  other
# is  :  is
# used  :  use
# to  :  to
# capture  :  captur
# shared  :  share
# features  :  featur
# .  :  .
# The  :  the
# major  :  major
# limitation  :  limit
# of  :  of
# this  :  thi
# framework  :  framework
# is  :  is
# that  :  that
# the  :  the
# shared  :  share
# feature  :  featur
# space  :  space
# could  :  could
# contain  :  contain
# some  :  some
# unnecessary  :  unnecessari
# task-specific  :  task-specif
# features  :  featur
# ,  :  ,
# while  :  while
# some  :  some
# sharable  :  sharabl
# features  :  featur
# could  :  could
# also  :  also
# be  :  be
# mixed  :  mix
# in  :  in
# private  :  privat
# space  :  space
# ,  :  ,
# suffering  :  suffer
# from  :  from
# feature  :  featur
# redundancy  :  redund
# .  :  .
# Taking  :  take
# the  :  the
# following  :  follow
# two  :  two
# sentences  :  sentenc
# as  :  as
# examples  :  exampl
# ,  :  ,
# which  :  which
# are  :  are
# extracted  :  extract
# from  :  from
# two  :  two
# different  :  differ
# sentiment  :  sentiment
# classification  :  classif
# tasks  :  task
# :  :  :
# Movie  :  movi
# reviews  :  review
# and  :  and
# Baby  :  babi
# products  :  product
# reviews  :  review
# .  :  .
# The  :  the
# infantile  :  infantil
# cart  :  cart
# is  :  is
# simple  :  simpl
# and  :  and
# easy  :  easi
# to  :  to
# use  :  use
# .  :  .
# This  :  thi
# kind  :  kind
# of  :  of
# humour  :  humour
# is  :  is
# infantile  :  infantil
# and  :  and
# boring  :  bore
# .  :  .
# The  :  the
# word  :  word
# �  :  �
# infantile  :  infantil
# �  :  �
# indicates  :  indic
# negative  :  neg
# sentiment  :  sentiment
# in  :  in
# Movie  :  movi
# task  :  task
# while  :  while
# it  :  it
# is  :  is
# neutral  :  neutral
# in  :  in
# Baby  :  babi
# task  :  task
# .  :  .
# However  :  howev
# ,  :  ,
# the  :  the
# general  :  gener
# shared-private  :  shared-priv
# model  :  model
# could  :  could
# place  :  place
# the  :  the
# task-specific  :  task-specif
# word  :  word
# �  :  �
# infantile  :  infantil
# �  :  �
# in  :  in
# a  :  a
# shared  :  share
# space  :  space
# ,  :  ,
# leaving  :  leav
# potential  :  potenti
# hazards  :  hazard
# for  :  for
# other  :  other
# tasks  :  task
# .  :  .
# Additionally  :  addit
# ,  :  ,
# the  :  the
# capacity  :  capac
# of  :  of
# shared  :  share
# space  :  space
# could  :  could
# also  :  also
# be  :  be
# wasted  :  wast
# by  :  by
# some  :  some
# unnecessary  :  unnecessari
# features  :  featur
# .  :  .
# To  :  To
# address  :  address
# this  :  thi
# problem  :  problem
# ,  :  ,
# in  :  in
# this  :  thi
# paper  :  paper
# we  :  we
# propose  :  propos
# an  :  an
# adversarial  :  adversari
# multi-task  :  multi-task
# framework  :  framework
# ,  :  ,
# in  :  in
# which  :  which
# the  :  the
# shared  :  share
# and  :  and
# private  :  privat
# feature  :  featur
# spaces  :  space
# are  :  are
# in  :  in
# herently  :  herent
# disjoint  :  disjoint
# by  :  by
# introducing  :  introduc
# orthogonality  :  orthogon
# constraints.Specifically  :  constraints.specif
# ,  :  ,
# we  :  we
# design  :  design
# a  :  a
# generic  :  gener
# shared  :  share
# private  :  privat
# learning  :  learn
# framework  :  framework
# to  :  to
# model  :  model
# the  :  the
# text  :  text
# sequence  :  sequenc
# .  :  .

# %%
print("=================== Twitter ===================")
for word in tokenized_twitter:
  print(word, " : ", ps.stem(word))
# Out:
# =================== Twitter ===================
# Reminds  :  remind
# me  :  me
# of  :  of
# Liberal  :  liber
# Immigration  :  immigr
# Fraudster  :  fraudster
# Monsef  :  monsef
# avoiding  :  avoid
# deportation  :  deport
# from  :  from
# Canada  :  canada
# .  :  .
# #cdnpoli  :  #cdnpoli
# #LPC  :  #lpc
# #CPCLDR  :  #cpcldr
# �  :  �
# �  :  �
# _  :  _
# https://t.co/ZOZOSe1CqQ  :  https://t.co/zozose1cqq
# #immigration  :  #immigr
# #integration  :  #integr
# #canada  :  #canada
# https://t.co/M5cKGyvV8F  :  https://t.co/m5ckgyvv8f
# We  :  We
# want  :  want
# controlled  :  control
# immigration  :  immigr
# that  :  that
# contributes  :  contribut
# positively  :  posit
# to  :  to
# the  :  the
# UK  :  UK
# economy  :  economi
# .  :  .
# Same  :  same
# as  :  as
# Australia  :  australia
# &  :  &
# Canada  :  canada
# .  :  .
# https://t.co/99mYliuOes  :  https://t.co/99myliuo
# Is  :  Is
# the  :  the
# new  :  new
# Manitoba  :  manitoba
# immigration  :  immigr
# fee  :  fee
# a  :  a
# head  :  head
# tax  :  tax
# ?  :  ?
# https://t.co/LsG7C3vLe9  :  https://t.co/lsg7c3vle9
# Canada  :  canada
# immigration  :  immigr
# profit  :  profit
# influence  :  influenc
# modernistic  :  modernist
# delhi  :  delhi
# yet  :  yet
# abhinav  :  abhinav
# :  :  :
# XKofy  :  xkofi
# https://t.co/becgusY2i6  :  https://t.co/becgusy2i6
# Canada  :  canada
# Immigration  :  immigr
# Minister  :  minist
# to  :  to
# �  :  �
# �  :  �
# �  :  �
# Substantially  :  substanti
# Increase  :  increas
# Immigration  :  immigr
# Numbers  :  number
# https://t.co/nEFw30MRaa  :  https://t.co/nefw30mraa
# https://t.co/cyI867PZRV  :  https://t.co/cyi867pzrv
# M  :  M
# �  :  �
# �  :  �
# me  :  me
# les  :  le
# #USA  :  #usa
# =p  :  =p
# ays  :  ay
# d'immigration  :  d'immigr
# par  :  par
# excellence  :  excel
# CONTR  :  contr
# �  :  �
# �  :  �
# LE  :  LE
# RIGOUREUSEMENT  :  rigoureus
# l'immigration  :  l'immigr
# et  :  et
# acc  :  acc
# �  :  �
# �  :  �
# s  :  s
# �  :  �
# �  :  �
# la  :  la
# #GreenCARD  :  #greencard
# !  :  !
# �  :  �
# �  :  �
# _  :  _
# https://t.co/IHpVhW2BaG  :  https://t.co/ihpvhw2bag
# what  :  what
# changes  :  chang
# should  :  should
# be  :  be
# made  :  made
# to  :  to
# Canada's  :  canada'
# immigration  :  immigr
# laws  :  law
# due  :  due
# to  :  to
# the  :  the
# influx  :  influx
# of  :  of
# immigration  :  immigr
# and  :  and
# violence  :  violenc
# ?  :  ?
# L  :  L
# �  :  �
# �  :  �
# immigration  :  immigr
# irr  :  irr
# �  :  �
# �  :  �
# guli  :  guli
# �  :  �
# �  :  �
# re  :  re
# au  :  au
# Canada  :  canada
# d  :  d
# �  :  �
# �  :  �
# cortiqu  :  cortiqu
# �  :  �
# �  :  �
# e  :  e
# en  :  en
# 5  :  5
# questions  :  question
# https://t.co/f4utO5A7ZF  :  https://t.co/f4uto5a7zf
# L'immigration  :  l'immigr
# irr  :  irr
# �  :  �
# �  :  �
# guli  :  guli
# �  :  �
# �  :  �
# re  :  re
# au  :  au
# Canada  :  canada
# d  :  d
# �  :  �
# �  :  �
# cortiqu  :  cortiqu
# �  :  �
# �  :  �
# e  :  e
# en  :  en
# 5  :  5
# questions  :  question
# -  :  -
# https://t.co/UiBsEZOqas  :  https://t.co/uibsezoqa
# https://t.co/j77dEvjoiX  :  https://t.co/j77devjoix
# https://t.co/XXDeIG7Dbu  :  https://t.co/xxdeig7dbu
# Will  :  will
# Media  :  media
# ask  :  ask
# the  :  the
# Liberals  :  liber
# if  :  if
# they  :  they
# actually  :  actual
# have  :  have
# a  :  a
# solid  :  solid
# plan  :  plan
# for  :  for
# Canada  :  canada
# _  :  _
# �  :  �
# �  :  �
# _  :  _
# �  :  �
# _  :  _
# ?  :  ?
# ?  :  ?
# From  :  from
# my  :  my
# view  :  view
# -  :  -
# -  :  -
# immigration  :  immigr
# out  :  out
# of  :  of
# C  :  C
# �  :  �
# �  :  �
# _  :  _
# https://t.co/YAgwmZ8ECp  :  https://t.co/yagwmz8ecp
# Dan  :  dan
# Murray  :  murray
# of  :  of
# �  :  �
# �  :  �
# Immigration  :  immigr
# Watch  :  watch
# Canada  :  canada
# is  :  is
# xenophobic  :  xenophob
# racist  :  racist
# fear-mongering  :  fear-mong
# liar  :  liar
# #racism  :  #racism
# #canada  :  #canada
# #cdnpoli  :  #cdnpoli
# #hatecrime  :  #hatecrim
# �  :  �
# �  :  �
# _  :  _
# https://t.co/kwZ3csvYxM  :  https://t.co/kwz3csvyxm
# Le  :  Le
# Canada  :  canada
# lance  :  lanc
# une  :  une
# vaste  :  vast
# campagne  :  campagn
# d'immigration  :  d'immigr
# pour  :  pour
# faire  :  fair
# face  :  face
# �  :  �
# �  :  �
# son  :  son
# besoin  :  besoin
# de  :  de
# main  :  main
# d  :  d
# '  :  '
# �  :  �
# �  :  �
# uvre  :  uvr
# https://t.co/kXdfMGTZzN  :  https://t.co/kxdfmgtzzn
# L  :  L
# �  :  �
# �  :  �
# #immigration  :  #immigr
# irr  :  irr
# �  :  �
# �  :  �
# guli  :  guli
# �  :  �
# �  :  �
# re  :  re
# au  :  au
# #Canada  :  #canada
# d  :  d
# �  :  �
# �  :  �
# cortiqu  :  cortiqu
# �  :  �
# �  :  �
# e  :  e
# en  :  en
# 5  :  5
# �  :  �
# �  :  �
# questions  :  question
# https://t.co/s3hu1OKKIG  :  https://t.co/s3hu1okkig
# I've  :  i'v
# read  :  read
# the  :  the
# Immigration  :  immigr
# laws  :  law
# of  :  of
# Canada  :  canada
# much  :  much
# stricter  :  stricter
# than  :  than
# the  :  the
# US  :  US
# Canada  :  canada
# Immigration  :  immigr
# Website  :  websit
# Traffic  :  traffic
# Surges  :  surg
# And  :  and
# Crashes  :  crash
# In  :  In
# Wake  :  wake
# Of  :  Of
# Trump  :  trump
# #fasttraffic  :  #fasttraff
# ,  :  ,
# #sitetraffic  :  #sitetraff
# ,  :  ,
# #website  :  #websit
# ,  :  ,
# #traffic  :  #traffic
# https://t.co/zRlJ26jnkC  :  https://t.co/zrlj26jnkc
# Mr  :  Mr
# Know-all  :  know-al
# of  :  of
# Canada  :  canada
# Immigration  :  immigr
# https://t.co/wTQK4QDiKI  :  https://t.co/wtqk4qdiki
# Move  :  move
# to  :  to
# Canada  :  canada
# Oh  :  Oh
# ,  :  ,
# immigration  :  immigr
# rules  :  rule
# ,  :  ,
# you  :  you
# can't  :  can't
# ...  :  ...
# https://t.co/5LIEVHO7A4  :  https://t.co/5lievho7a4
# #OnThisDay  :  #onthisday
# Annette  :  annett
# Toft  :  toft
# becomes  :  becom
# Canada's  :  canada'
# 2  :  2
# millionth  :  millionth
# immigrant  :  immigr
# since  :  sinc
# 1945  :  1945
# .  :  .
# Do  :  Do
# you  :  you
# know  :  know
# your  :  your
# family's  :  family'
# immigration  :  immigr
# st  :  st
# �  :  �
# �  :  �
# _  :  _
# https://t.co/UvRuw8eR1b  :  https://t.co/uvruw8er1b
# .  :  .
# profiles  :  profil
# Canada's  :  canada'
# open  :  open
# immigration  :  immigr
# policies  :  polici
# &  :  &
# how  :  how
# they  :  they
# contribute  :  contribut
# to  :  to
# our  :  our
# economic  :  econom
# success  :  success
# :  :  :
# �  :  �
# �  :  �
# _  :  _
# https://t.co/4K84EE8Y63  :  https://t.co/4k84ee8y63
# Hundreds  :  hundr
# may  :  may
# lose  :  lose
# Canadian  :  canadian
# citizenship  :  citizenship
# ,  :  ,
# resident  :  resid
# status  :  statu
# because  :  becaus
# of  :  of
# one  :  one
# corrupt  :  corrupt
# immigration  :  immigr
# consultant  :  consult
# https://t.co/x2IfO0EXI2  :  https://t.co/x2ifo0exi2
# Immigration  :  immigr
# for  :  for
# canada  :  canada
# without  :  without
# india  :  india
# :  :  :
# an  :  an
# compassionate  :  compassion
# handle  :  handl
# :  :  :
# deyFy  :  deyfi
# "  :  "
# #Jamaican  :  #jamaican
# #immigrants  :  #immigr
# #Canada  :  #canada
# https://t.co/vcmfYGadR5  :  https://t.co/vcmfygadr5
# #statistics  :  #statist
# #immigration  :  #immigr
# "  :  "
# Mexican  :  mexican
# visa  :  visa
# lift  :  lift
# expected  :  expect
# to  :  to
# cost  :  cost
# Canada  :  canada
# $  :  $
# 262M  :  262m
# over  :  over
# a  :  a
# decade  :  decad
# https://t.co/9i72fRhtij  :  https://t.co/9i72frhtij
# Are  :  are
# people  :  peopl
# still  :  still
# moving  :  move
# to  :  to
# #Canada  :  #canada
# ?  :  ?
# ?  :  ?
# ?  :  ?
# Oh  :  Oh
# that's  :  that'
# right  :  right
# ,  :  ,
# they  :  they
# have  :  have
# real  :  real
# immigration  :  immigr
# laws  :  law
# and  :  and
# it's  :  it'
# �  :  �
# �  :  �
# _  :  _
# https://t.co/0C5OBfmxLG  :  https://t.co/0c5obfmxlg
# Here  :  here
# are  :  are
# more  :  more
# details  :  detail
# on  :  on
# the  :  the
# Richmond  :  richmond
# ,  :  ,
# B  :  B
# .  :  .
# C  :  C
# .  :  .
# Immigration  :  immigr
# Consultant  :  consult
# Sunny  :  sunni
# Wang  :  wang
# who  :  who
# was  :  wa
# sentenced  :  sentenc
# to  :  to
# 7  :  7
# years  :  year
# in  :  in
# ...  :  ...
# https://t.co/YXH5W53srO  :  https://t.co/yxh5w53sro
# I  :  I
# added  :  ad
# a  :  a
# video  :  video
# to  :  to
# a  :  a
# playlist  :  playlist
# https://t.co/CnEyWN40x3  :  https://t.co/cneywn40x3
# Funny  :  funni
# Talking  :  talk
# of  :  of
# Haryanavi  :  haryanavi
# Jat  :  jat
# with  :  with
# Canada  :  canada
# Immigration  :  immigr
# Girl  :  girl
# Agent  :  agent
# Mexicans  :  mexican
# Can  :  can
# Now  :  now
# Travel  :  travel
# Visa-Free  :  visa-fre
# To  :  To
# Canada  :  canada
# https://t.co/Ec3XHORO2s  :  https://t.co/ec3xhoro2
# https://t.co/RQRr5nebcG  :  https://t.co/rqrr5nebcg
# L  :  L
# �  :  �
# �  :  �
# immigration  :  immigr
# irr  :  irr
# �  :  �
# �  :  �
# guli  :  guli
# �  :  �
# �  :  �
# re  :  re
# au  :  au
# Canada  :  canada
# d  :  d
# �  :  �
# �  :  �
# cortiqu  :  cortiqu
# �  :  �
# �  :  �
# e  :  e
# en  :  en
# 5  :  5
# �  :  �
# �  :  �
# questions  :  question
# https://t.co/DkpuKyWmaK  :  https://t.co/dkpukywmak
# Hes  :  he
# the  :  the
# POS  :  po
# that  :  that
# ramped  :  ramp
# up  :  up
# immigration  :  immigr
# for  :  for
# Canada  :  canada
# ,  :  ,
# among  :  among
# other  :  other
# globalist  :  globalist
# policies  :  polici
# .  :  .
# Canada  :  canada
# lifted  :  lift
# visa  :  visa
# requirements  :  requir
# to  :  to
# Mexico  :  mexico
# as  :  as
# of  :  of
# Dec  :  dec
# 1  :  1
# ,  :  ,
# 2016  :  2016
# .  :  .
# Thoughts  :  thought
# ?  :  ?
# #visa  :  #visa
# #immigration  :  #immigr
# people  :  peopl
# Keep  :  keep
# praising  :  prais
# Canada  :  canada
# and  :  and
# Canada  :  canada
# has  :  ha
# way  :  way
# stricter  :  stricter
# immigration  :  immigr
# laws  :  law
# then  :  then
# us  :  us
# they  :  they
# willl  :  willl
# boot  :  boot
# your  :  your
# liberal  :  liber
# American  :  american
# ass  :  ass

# %%
print("=================== Student Feedback ===================")
for word in tokenized_student_feedback:
  print(word, " : ", ps.stem(word))
# Out:
# =================== Student Feedback ===================
# Honestly  :  honestli
# last  :  last
# seven  :  seven
# lectures  :  lectur
# are  :  are
# good  :  good
# .  :  .
# Lectures  :  lectur
# are  :  are
# understandable  :  understand
# .  :  .
# Lecture  :  lectur
# slides  :  slide
# are  :  are
# very  :  veri
# useful  :  use
# to  :  to
# self-study  :  self-studi
# also  :  also
# .  :  .
# The  :  the
# given  :  given
# opportunity  :  opportun
# to  :  to
# ask  :  ask
# questions  :  question
# from  :  from
# the  :  the
# lecturer  :  lectur
# is  :  is
# appreciative  :  appreci
# .  :  .
# "  :  "
# Good  :  good
# :)  :  :)
# <  :  <
# br  :  br
# /  :  /
# >  :  >
# please  :  pleas
# do  :  do
# recap  :  recap
# at  :  at
# class  :  class
# starting  :  start
# it's  :  it'
# better  :  better
# for  :  for
# us  :  us
# .  :  .
# <  :  <
# br  :  br
# /  :  /
# >  :  >
# sometimes  :  sometim
# teaching  :  teach
# speed  :  speed
# is  :  is
# very  :  veri
# high  :  high
# .  :  .
# <  :  <
# br  :  br
# /  :  /
# >  :  >
# <  :  <
# br  :  br
# /  :  /
# >  :  >
# Thanks  :  thank
# !  :  !
# :)  :  :)
# <  :  <
# br  :  br
# /  :  /
# >  :  >
# "  :  "
# The  :  the
# lectures  :  lectur
# are  :  are
# good  :  good
# ..  :  ..
# but  :  but
# a  :  a
# bit  :  bit
# speed  :  speed
# .  :  .
# A  :  A
# in  :  in
# class  :  class
# working  :  work
# activity  :  activ
# is  :  is
# a  :  a
# must  :  must
# one.So  :  one.so
# please  :  pleas
# take  :  take
# another  :  anoth
# hour  :  hour
# in  :  in
# thursdays  :  thursday
# madame  :  madam
# .  :  .
# "  :  "
# <  :  <
# br  :  br
# /  :  /
# >  :  >
# We  :  We
# can  :  can
# hear  :  hear
# your  :  your
# voice  :  voic
# clearly  :  clearli
# and  :  and
# can  :  can
# understand  :  understand
# the  :  the
# things  :  thing
# you  :  you
# teach  :  teach
# .  :  .
# Presentation  :  present
# slides  :  slide
# also  :  also
# good  :  good
# source  :  sourc
# to  :  to
# refer  :  refer
# .  :  .
# lf  :  lf
# you  :  you
# can  :  can
# do  :  do
# more  :  more
# example  :  exampl
# questions  :  question
# within  :  within
# the  :  the
# classroom  :  classroom
# and  :  and
# it  :  it
# will  :  will
# help  :  help
# us  :  us
# to  :  to
# understand  :  understand
# the  :  the
# principles  :  principl
# well  :  well
# .  :  .
# <  :  <
# br  :  br
# /  :  /
# >  :  >
# "  :  "
# Lectures  :  lectur
# was  :  wa
# well  :  well
# structured  :  structur
# and  :  and
# well  :  well
# organized  :  organ
# .  :  .
# It  :  It
# was  :  wa
# easy  :  easi
# to  :  to
# understand  :  understand
# .  :  .
# Lecture  :  lectur
# slides  :  slide
# and  :  and
# labs  :  lab
# were  :  were
# also  :  also
# well  :  well
# organized  :  organ
# .  :  .
# Lectures  :  lectur
# were  :  were
# good  :  good
# .  :  .
# understandable  :  understand
# .  :  .
# The  :  the
# lecture  :  lectur
# slides  :  slide
# were  :  were
# well  :  well
# organized  :  organ
# and  :  and
# the  :  the
# examples  :  exampl
# done  :  done
# in  :  in
# the  :  the
# class  :  class
# helped  :  help
# a  :  a
# lot  :  lot
# to  :  to
# learn  :  learn
# this  :  thi
# new  :  new
# language  :  languag
# and  :  and
# also  :  also
# the  :  the
# principles  :  principl
# of  :  of
# OOP  :  oop
# .  :  .
# Motivated  :  motiv
# to  :  to
# well  :  well
# .  :  .
# Would  :  would
# have  :  have
# been  :  been
# better  :  better
# if  :  if
# we  :  we
# discussed  :  discuss
# more  :  more
# about  :  about
# the  :  the
# solutions  :  solut
# of  :  of
# coding  :  code
# exercisers  :  exercis
# .  :  .
# I  :  I
# think  :  think
# i  :  i
# learned  :  learn
# a  :  a
# lot  :  lot
# from  :  from
# the  :  the
# codes  :  code
# you  :  you
# write  :  write
# in  :  in
# the  :  the
# board  :  board
# .  :  .
# When  :  when
# i  :  i
# compare  :  compar
# my  :  my
# codes  :  code
# with  :  with
# yours  :  your
# i  :  i
# can  :  can
# learn  :  learn
# about  :  about
# my  :  my
# mistakes  :  mistak
# and  :  and
# good  :  good
# coding  :  code
# practices  :  practic
# that  :  that
# i  :  i
# should  :  should
# follow  :  follow
# .  :  .
# There  :  there
# fore  :  fore
# i  :  i
# think  :  think
# it  :  it
# would  :  would
# be  :  be
# great  :  great
# if  :  if
# we  :  we
# can  :  can
# discuss  :  discuss
# more  :  more
# examples  :  exampl
# in  :  in
# the  :  the
# class  :  class
# .  :  .
# madam  :  madam
# explained  :  explain
# the  :  the
# oop  :  oop
# concepts  :  concept
# clearly  :  clearli
# with  :  with
# examples.lectures  :  examples.lectur
# were  :  were
# interesting.we  :  interesting.w
# want  :  want
# more  :  more
# scenario  :  scenario
# examples  :  exampl
# and  :  and
# answers  :  answer
# with  :  with
# explanations  :  explan
# in  :  in
# future  :  futur
# .  :  .
# I  :  I
# satisfy  :  satisfi
# about  :  about
# first  :  first
# 7  :  7
# lectures  :  lectur
# .  :  .
# That  :  that
# way  :  way
# of  :  of
# teaching  :  teach
# is  :  is
# really  :  realli
# good  :  good
# for  :  for
# coming  :  come
# lectures  :  lectur
# too  :  too
# .  :  .
# lectuers  :  lectuer
# are  :  are
# very  :  veri
# good  :  good
# .  :  .
# take  :  take
# good  :  good
# effort  :  effort
# to  :  to
# make  :  make
# undersatand  :  undersatand
# every  :  everi
# student  :  student
# in  :  in
# the  :  the
# room  :  room
# .  :  .
# very  :  veri
# helpfull  :  helpful
# .  :  .
# I  :  I
# was  :  wa
# able  :  abl
# to  :  to
# obtain  :  obtain
# a  :  a
# clear  :  clear
# picture  :  pictur
# about  :  about
# OOP  :  oop
# and  :  and
# its  :  it
# concepts  :  concept
# .  :  .
# "  :  "
# lecture  :  lectur
# slides  :  slide
# ,  :  ,
# explanations  :  explan
# were  :  were
# very  :  veri
# clear  :  clear
# .  :  .
# <  :  <
# br  :  br
# /  :  /
# >  :  >
# it's  :  it'
# very  :  veri
# good  :  good
# to  :  to
# letting  :  let
# ask  :  ask
# questions  :  question
# and  :  and
# explain  :  explain
# again  :  again
# with  :  with
# suitable  :  suitabl
# examples  :  exampl
# .  :  .
# <  :  <
# br  :  br
# /  :  /
# >  :  >
# sometimes  :  sometim
# ,  :  ,
# some  :  some
# codes  :  code
# on  :  on
# white  :  white
# board  :  board
# were  :  were
# unclear  :  unclear
# at  :  at
# the  :  the
# back  :  back
# .  :  .
# <  :  <
# br  :  br
# /  :  /
# >  :  >
# overall  :  overal
# very  :  veri
# good  :  good
# !  :  !
# !  :  !
# !  :  !
# <  :  <
# br  :  br
# /  :  /
# >  :  >
# "  :  "
# The  :  the
# lectures  :  lectur
# were  :  were
# good  :  good
# and  :  and
# clear  :  clear
# .  :  .
# And  :  and
# they  :  they
# weren't  :  weren't
# too  :  too
# fast  :  fast
# .  :  .
# Writing  :  write
# code  :  code
# was  :  wa
# somewhat  :  somewhat
# confusing  :  confus
# because  :  becaus
# I  :  I
# didn't  :  didn't
# know  :  know
# java  :  java
# before  :  befor
# .  :  .
# Actually  :  actual
# teaching  :  teach
# is  :  is
# very  :  veri
# good  :  good
# and  :  and
# can  :  can
# understand  :  understand
# easily  :  easili
# the  :  the
# concepts  :  concept
# by  :  by
# examples  :  exampl
# which  :  which
# are  :  are
# given  :  given
# in  :  in
# the  :  the
# class.it  :  class.it
# will  :  will
# be  :  be
# more  :  more
# helpful  :  help
# if  :  if
# provide  :  provid
# solved  :  solv
# questions  :  question
# as  :  as
# well  :  well
# !  :  !
# .  :  .
# thankyou  :  thankyou
